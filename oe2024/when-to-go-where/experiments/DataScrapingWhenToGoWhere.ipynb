# %% [markdown]
# <a href="https://colab.research.google.com/github/tetherless-world/ontology-engineering/blob/when-to-go-where/oe2024/when-to-go-where/experiments/DataScrapingWhenToGoWhere.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gspread gspread_dataframe
# !pip install rdflib
# !pip install lxml
# Out:
# Requirement already satisfied: gspread in /usr/local/lib/python3.10/dist-packages (6.0.2)
# Requirement already satisfied: gspread_dataframe in /usr/local/lib/python3.10/dist-packages (3.3.1)
# Requirement already satisfied: google-auth>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from gspread) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from gspread) (1.2.1)
# Requirement already satisfied: StrEnum==0.4.15 in /usr/local/lib/python3.10/dist-packages (from gspread) (0.4.15)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from gspread_dataframe) (2.2.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from gspread_dataframe) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.1)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->gspread_dataframe) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->gspread_dataframe) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->gspread_dataframe) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->gspread_dataframe) (2024.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2024.8.30)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.10/dist-packages (7.1.1)
# Requirement already satisfied: isodate<1.0.0,>=0.7.2 in /usr/local/lib/python3.10/dist-packages (from rdflib) (0.7.2)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from rdflib) (3.2.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (5.3.0)

# %%
'''
Imports
'''
from bs4 import BeautifulSoup
import requests
import re
from google.colab import auth
from google.auth.transport.requests import Request
import gspread
from gspread_dataframe import get_as_dataframe
from rdflib import Graph, URIRef, Literal, Namespace
from rdflib.namespace import RDF, OWL, XSD

# %%
# Define namespaces
OE_WTGW = Namespace("https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/")
OE_WTGW_IND = Namespace("https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/")
LOCATIONS = Namespace("https://www.omg.org/spec/Commons/Locations/")
CMNS_AV = Namespace("https://www.omg.org/spec/Commons/AnnotationVocabulary/")
DCT = Namespace("http://purl.org/dc/terms/")
SKOS = Namespace("http://www.w3.org/2004/02/skos/core#")
RDFS = Namespace("http://www.w3.org/2000/01/rdf-schema#")

def create_graph():
  # Create a graph
  g = Graph(base="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/")

  # Bind prefixes
  g.bind("Locations", LOCATIONS)
  g.bind("cmns-av", CMNS_AV)
  g.bind("dct", DCT)
  g.bind("oe-wtgw", OE_WTGW)
  g.bind("oe-wtgw-ind", OE_WTGW_IND)
  g.bind("owl", OWL)
  g.bind("rdf", RDF)
  g.bind("rdfs", RDFS)
  g.bind("skos", SKOS)
  g.bind("xsd", XSD)

  # Define ontology metadata
  ontology_uri = URIRef("https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/")
  g.add((ontology_uri, RDF.type, OWL.Ontology))
  g.add((ontology_uri, DCT.abstract, Literal("""When to go where is a project that aims to promote outdoor exploration across the 63 National Parks in the United States. We would like to give people a tool that will allow them to find national parks that will fit any preferences that they may have. We want to give people as few excuses as possible for not pursing outdoor activities such as camping and hiking.

To achieve this we are creating a semantically enabled application that will leverage an OWL ontology to answer user questions. Our interface will give users options to input preferences and using semantics we will identify the best parks that match a users particular criteria.""")))
  g.add((ontology_uri, DCT.abstract, Literal("some description")))
  g.add((ontology_uri, DCT.creator, Literal("Annabelle Choi")))
  g.add((ontology_uri, DCT.creator, Literal("Ben Rodgers")))
  g.add((ontology_uri, DCT.creator, Literal("Samyuth Sagi")))
  g.add((ontology_uri, DCT.creator, Literal("Tyler Layton")))
  g.add((ontology_uri, DCT.license, Literal("https://when-to-go-where--rpi-ontology-engineering.netlify.app/oe2024/when-to-go-where/license", datatype=XSD.anyURI)))
  g.add((ontology_uri, OWL.imports, OE_WTGW[""]))
  g.add((ontology_uri, DCT.modified, Literal("2024-11-30", datatype=XSD.date)))
  g.add((ontology_uri, DCT.publisher, Literal("WhenToGoWhere")))
  g.add((ontology_uri, OWL.priorVersion, URIRef("https://github.com/tetherless-world/ontology-engineering/blob/dac8dda75fb576d8551123076e10627d716549d9/oe2024/when-to-go-where/WhenToGoWhere-individuals.rdf")))
  g.add((ontology_uri, OWL.priorVersion, URIRef("https://github.com/tetherless-world/ontology-engineering/blob/114aa8ad617d0eeea3570d8d0f7a65eb21b862a9/oe2024/when-to-go-where/WhenToGoWhere-individuals.rdf")))
  g.add((ontology_uri, CMNS_AV.copyright, Literal(
      "Copyright (c) 2024 Annabelle Choi, Ben Rodgers, Samyuth Sagi, Tyler Layton"
  )))
  g.add((ontology_uri, OWL.versionIRI, OE_WTGW_IND["5.0"]))

  # # dummy triple to get xsd import
  # g.add((URIRef("http://example.org/dummy"), RDF.type, XSD.string))

  return g

# Function to convert names to camel case
def convert_to_camel_case(name):
    # Remove non-alphanumeric characters
    name = re.sub(r'[^A-Za-z0-9 ]+', '', name)
    # Split by spaces, capitalize each word, and join without spaces
    return ''.join(word.capitalize() for word in name.split())

# Function to create park individual in RDF
def add_park_individual(g, name, state=""):
    # Convert names to camel case
    camel_case_name = convert_to_camel_case(name)

    # Create the URI for the individual
    individual_uri = OE_WTGW_IND[camel_case_name]

    # Add the RDF type for NationalPark
    g.add((individual_uri, RDF.type, OWL.NamedIndividual))
    g.add((individual_uri, RDF.type, OE_WTGW.NationalPark))
    if name == "Wrangell St Elias National Park":
      g.add((individual_uri, RDFS.label, Literal("Wrangell-St. Elias National Park".lower())))
    else:
      g.add((individual_uri, RDFS.label, Literal(name.lower())))


    # With states add triples pointing at the state and pointing back at park
    if state:
      state = convert_to_camel_case(state)
      g.add((individual_uri, OE_WTGW.hasState, OE_WTGW_IND[state]))
      g.add((OE_WTGW_IND[state], OE_WTGW.hasPark, individual_uri))


def add_hike_individual(g, name, hike_difficulty, hike_len, park):
    # Convert names to camel case
    camel_case_name = convert_to_camel_case(name)
    hike_difficulty = convert_to_camel_case(hike_difficulty)
    park = convert_to_camel_case(park)

    # Create the URI for the individual
    individual_uri = OE_WTGW_IND[camel_case_name]

    # Add triples to the graph
    g.add((individual_uri, RDF.type, OWL.NamedIndividual))
    g.add((individual_uri, RDF.type, OE_WTGW.Hike))
    g.add((individual_uri, RDFS.label, Literal(name.lower())))
    g.add((individual_uri, OE_WTGW.hasDifficulty, OE_WTGW_IND[hike_difficulty]))
    g.add((individual_uri, OE_WTGW.hasDistance, Literal(hike_len, datatype=XSD.decimal)))
    g.add((individual_uri, OE_WTGW.isHikeOf, OE_WTGW_IND[park]))

    # Add triple pointing back to park
    g.add((OE_WTGW_IND[park], OE_WTGW.hasHike, individual_uri))


def add_location_individual(g, name, latitude, longitude):
  # Convert names to camel case
  camel_case_name = convert_to_camel_case(name) + "Location"

  # Create the URI for the individual
  individual_uri = OE_WTGW_IND[camel_case_name]

  # Add triples to the graph
  g.add((individual_uri, RDF.type, OWL.NamedIndividual))
  g.add((individual_uri, RDF.type, LOCATIONS.PhysicalLocation))
  g.add((individual_uri, RDFS.label, Literal(name.lower() + " location")))
  g.add((individual_uri, LOCATIONS.hasLatitude, Literal(latitude, datatype=XSD.decimal)))
  g.add((individual_uri, LOCATIONS.hasLongitude, Literal(longitude, datatype=XSD.decimal)))

  # Add triple pointing to park
  g.add((OE_WTGW_IND[convert_to_camel_case(name)], LOCATIONS.hasLocation, individual_uri))

def add_visitors_individual(g, park_name, season, visitors):
    camel_case_name = convert_to_camel_case(park_name)
    individual_name = camel_case_name + season + "AvgVisitors"
    individual_label = park_name.lower() + " " + season.lower() + " average visitors"

    # Create the URI for the individual
    individual_uri = OE_WTGW_IND[individual_name]

    # Add triples to the graph
    g.add((individual_uri, RDF.type, OWL.NamedIndividual))
    g.add((individual_uri, RDF.type, OE_WTGW['AvgSeasonalVisitors']))
    g.add((individual_uri, RDFS.label, Literal(individual_label)))
    g.add((individual_uri, OE_WTGW.hasSeason, OE_WTGW_IND[season]))
    g.add((individual_uri, OE_WTGW.hasVisitors, Literal(visitors, datatype=XSD.integer)))

def add_state_individual(g, name):
    camel_case_name = convert_to_camel_case(name)

    # Create the URI for the individual
    individual_uri = OE_WTGW_IND[camel_case_name]

    # Add triples to the graph
    g.add((individual_uri, RDF.type, OWL.NamedIndividual))
    g.add((individual_uri, RDFS.label, Literal(name.lower())))
    g.add((individual_uri, RDF.type, OE_WTGW.State))

def add_animal_individual(g, name, cat, park):
    camel_case_name = convert_to_camel_case(name)

    # Create the URI for the individual
    individual_uri = OE_WTGW_IND[camel_case_name]

    # Add triples to the graph
    g.add((individual_uri, RDF.type, OWL.NamedIndividual))
    g.add((individual_uri, RDFS.label, Literal(name.lower())))
    g.add((individual_uri, RDF.type, OE_WTGW.Animal))
    g.add((individual_uri, OE_WTGW.isAnimalType, OE_WTGW_IND[cat]))
    g.add((individual_uri, OE_WTGW.isAnimalOf, OE_WTGW_IND[park]))

def add_temperature_individual(g, name, season, temperature):
  camel_case_name = convert_to_camel_case(name)
  individual_name = camel_case_name + season + "AvgTemperature"
  individual_label = name.lower() + " " + season.lower() + " average temperature"

  # Create the URI for the individual
  individual_uri = OE_WTGW_IND[individual_name]

  # Add triples to the graph
  g.add((individual_uri, RDF.type, OWL.NamedIndividual))
  g.add((individual_uri, RDFS.label, Literal(individual_label)))
  g.add((individual_uri, RDF.type, OE_WTGW['AvgSeasonalTemperature']))
  g.add((individual_uri, OE_WTGW.temperatureHasSeason, OE_WTGW_IND[season]))
  g.add((individual_uri, OE_WTGW.hasTemperature, Literal(temperature, datatype=XSD.decimal)))

  # Add triple pointing back to park
  g.add((OE_WTGW_IND[camel_case_name], OE_WTGW.hasAvgSeasonalTemperature, individual_uri))

def add_generic_individual(g, name):
    # Create the URI for the individual
    individual_uri = OE_WTGW_IND[name]

    # Add triples to the graph
    g.add((individual_uri, RDF.type, OWL.NamedIndividual))
    g.add((individual_uri, RDFS.label, Literal(name.lower())))

# Serialize the graph
def print_graph(g):
  rdf_data = g.serialize(format="pretty-xml", encoding="utf-8").decode("utf-8")

  if 'xmlns:oe-wtgw-ind=' not in rdf_data:
      rdf_data = rdf_data.replace(
          '<rdf:RDF',
          '<rdf:RDF\n  xmlns:oe-wtgw-ind="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/"\n xmlns:xsd="http://www.w3.org/2001/XMLSchema#"\n',
          1
      )

  # Print the output
  print(rdf_data)

# test graph
test_g = create_graph()

# print_graph(test_g)

# test trail
name = "The Watchman Trail"
hike_difficuty = "Moderate"
hike_len = "3.3"
park = "Zion National Park"
add_hike_individual(test_g, name, hike_difficuty, hike_len, park)

# test park
add_park_individual(test_g, park)

# test park 2
name = "Acadia National Park"
add_park_individual(test_g, name)
add_location_individual(test_g, name, 44.33, -68)
add_state_individual(test_g, "Maine")
add_park_individual(test_g, name, state="Maine")
add_temperature_individual(test_g, name, "Spring", 60)

add_animal_individual(test_g, "Moose", "Mammal", "AcadiaNationalPark")

# # season
# seasons = ["Spring", "Summer", "Fall", "Winter"]
# for season in seasons:
#   add_generic_individual(test_g, season)
#   test_g.add((OE_WTGW_IND[season], RDF.type, OE_WTGW['Season']))

# # difficulties
# difficulties = ["Easy", "Moderate", "Challenging"]
# for difficulty in difficulties:
#   add_generic_individual(test_g, difficulty)
#   test_g.add((OE_WTGW_IND[difficulty], RDF.type, OE_WTGW['Difficulty']))

add_visitors_individual(test_g, "Acadia National Park", "Spring", 60)

print_graph(test_g)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <rdf:RDF
#   xmlns:oe-wtgw-ind="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/"
#  xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#  xml:base="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/"
#   xmlns:oe-wtgw="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/"
#   xmlns:cmns-av="https://www.omg.org/spec/Commons/AnnotationVocabulary/"
#   xmlns:dct="http://purl.org/dc/terms/"
#   xmlns:Locations="https://www.omg.org/spec/Commons/Locations/"
#   xmlns:owl="http://www.w3.org/2002/07/owl#"
#   xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#   xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
# >
#   <owl:Ontology rdf:about="">
#     <dct:abstract>When to go where is a project that aims to promote outdoor exploration across the 63 National Parks in the United States. We would like to give people a tool that will allow them to find national parks that will fit any preferences that they may have. We want to give people as few excuses as possible for not pursing outdoor activities such as camping and hiking.
#
# To achieve this we are creating a semantically enabled application that will leverage an OWL ontology to answer user questions. Our interface will give users options to input preferences and using semantics we will identify the best parks that match a users particular criteria.</dct:abstract>
#     <dct:abstract>some description</dct:abstract>
#     <dct:creator>Annabelle Choi</dct:creator>
#     <dct:creator>Ben Rodgers</dct:creator>
#     <dct:creator>Samyuth Sagi</dct:creator>
#     <dct:creator>Tyler Layton</dct:creator>
#     <dct:license rdf:datatype="http://www.w3.org/2001/XMLSchema#anyURI">https://when-to-go-where--rpi-ontology-engineering.netlify.app/oe2024/when-to-go-where/license</dct:license>
#     <owl:imports rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/"/>
#     <dct:modified rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2024-11-30</dct:modified>
#     <dct:publisher>WhenToGoWhere</dct:publisher>
#     <owl:priorVersion rdf:resource="https://github.com/tetherless-world/ontology-engineering/blob/dac8dda75fb576d8551123076e10627d716549d9/oe2024/when-to-go-where/WhenToGoWhere-individuals.rdf"/>
#     <owl:priorVersion rdf:resource="https://github.com/tetherless-world/ontology-engineering/blob/114aa8ad617d0eeea3570d8d0f7a65eb21b862a9/oe2024/when-to-go-where/WhenToGoWhere-individuals.rdf"/>
#     <cmns-av:copyright>Copyright (c) 2024 Annabelle Choi, Ben Rodgers, Samyuth Sagi, Tyler Layton</cmns-av:copyright>
#     <owl:versionIRI rdf:resource="5.0"/>
#   </owl:Ontology>
#   <owl:NamedIndividual rdf:about="AcadiaNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>acadia national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">60</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Moose">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>moose</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Mammal"/>
#     <oe-wtgw:isAnimalOf>
#       <owl:NamedIndividual rdf:about="AcadiaNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>acadia national park</rdfs:label>
#         <Locations:hasLocation rdf:resource="AcadiaNationalParkLocation"/>
#         <oe-wtgw:hasState rdf:resource="Maine"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="AcadiaNationalParkSpringAvgTemperature"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isAnimalOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="AcadiaNationalParkSpringAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>acadia national park spring average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">60</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Maine">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>maine</rdfs:label>
#     <oe-wtgw:hasPark rdf:resource="AcadiaNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="TheWatchmanTrail">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>the watchman trail</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.3</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="ZionNationalPark">
#         <oe-wtgw:hasHike rdf:resource="TheWatchmanTrail"/>
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>zion national park</rdfs:label>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="AcadiaNationalParkLocation">
#     <rdf:type rdf:resource="https://www.omg.org/spec/Commons/Locations/PhysicalLocation"/>
#     <rdfs:label>acadia national park location</rdfs:label>
#     <Locations:hasLatitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">44.33</Locations:hasLatitude>
#     <Locations:hasLongitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">-68</Locations:hasLongitude>
#   </owl:NamedIndividual>
# </rdf:RDF>

# %%
# Create the rdf graph
graph = create_graph()

# Add some basic individuals
# season
seasons = ["Spring", "Summer", "Fall", "Winter"]
for season in seasons:
  add_generic_individual(graph, season)
  graph.add((OE_WTGW_IND[season], RDF.type, OE_WTGW['Season']))

# difficulties
difficulties = ["Easy", "Moderate", "Challenging"]
for difficulty in difficulties:
  add_generic_individual(graph, difficulty)
  graph.add((OE_WTGW_IND[difficulty], RDF.type, OE_WTGW['Difficulty']))

# animal types
animal_types = ["Amphibian", "Bird", "Fish", "Insect", "Mammal", "Reptile"]
for animal_type in animal_types:
  add_generic_individual(graph, animal_type)
  graph.add((OE_WTGW_IND[animal_type], RDF.type, OE_WTGW['AnimalType']))

# states all 50
states = [
    "Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut",
    "Delaware", "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa",
    "Kansas", "Kentucky", "Louisiana", "Maine", "Maryland", "Massachusetts", "Michigan",
    "Minnesota", "Mississippi", "Missouri", "Montana", "Nebraska", "Nevada", "New Hampshire",
    "New Jersey", "New Mexico", "New York", "North Carolina", "North Dakota", "Ohio", "Oklahoma",
    "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", "South Dakota", "Tennessee", "Texas",
    "Utah", "Vermont", "Virginia", "Washington", "West Virginia", "Wisconsin", "Wyoming", "U.S. Virgin Islands"
]
for state in states:
  add_state_individual(graph, state)

print_graph(graph)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <rdf:RDF
#   xmlns:oe-wtgw-ind="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/"
#  xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#  xml:base="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/"
#   xmlns:owl="http://www.w3.org/2002/07/owl#"
#   xmlns:dct="http://purl.org/dc/terms/"
#   xmlns:oe-wtgw="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/"
#   xmlns:cmns-av="https://www.omg.org/spec/Commons/AnnotationVocabulary/"
#   xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#   xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
# >
#   <owl:NamedIndividual rdf:about="Kansas">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>kansas</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NewMexico">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>new mexico</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NewYork">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>new york</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Wisconsin">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>wisconsin</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Louisiana">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>louisiana</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Kentucky">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>kentucky</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:Ontology rdf:about="">
#     <dct:abstract>When to go where is a project that aims to promote outdoor exploration across the 63 National Parks in the United States. We would like to give people a tool that will allow them to find national parks that will fit any preferences that they may have. We want to give people as few excuses as possible for not pursing outdoor activities such as camping and hiking.
#
# To achieve this we are creating a semantically enabled application that will leverage an OWL ontology to answer user questions. Our interface will give users options to input preferences and using semantics we will identify the best parks that match a users particular criteria.</dct:abstract>
#     <dct:abstract>some description</dct:abstract>
#     <dct:creator>Annabelle Choi</dct:creator>
#     <dct:creator>Ben Rodgers</dct:creator>
#     <dct:creator>Samyuth Sagi</dct:creator>
#     <dct:creator>Tyler Layton</dct:creator>
#     <dct:license rdf:datatype="http://www.w3.org/2001/XMLSchema#anyURI">https://when-to-go-where--rpi-ontology-engineering.netlify.app/oe2024/when-to-go-where/license</dct:license>
#     <owl:imports rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/"/>
#     <dct:modified rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2024-11-30</dct:modified>
#     <dct:publisher>WhenToGoWhere</dct:publisher>
#     <owl:priorVersion rdf:resource="https://github.com/tetherless-world/ontology-engineering/blob/dac8dda75fb576d8551123076e10627d716549d9/oe2024/when-to-go-where/WhenToGoWhere-individuals.rdf"/>
#     <owl:priorVersion rdf:resource="https://github.com/tetherless-world/ontology-engineering/blob/114aa8ad617d0eeea3570d8d0f7a65eb21b862a9/oe2024/when-to-go-where/WhenToGoWhere-individuals.rdf"/>
#     <cmns-av:copyright>Copyright (c) 2024 Annabelle Choi, Ben Rodgers, Samyuth Sagi, Tyler Layton</cmns-av:copyright>
#     <owl:versionIRI rdf:resource="5.0"/>
#   </owl:Ontology>
#   <owl:NamedIndividual rdf:about="Massachusetts">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>massachusetts</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Challenging">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Difficulty"/>
#     <rdfs:label>challenging</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="RhodeIsland">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>rhode island</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Missouri">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>missouri</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NewHampshire">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>new hampshire</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Fish">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AnimalType"/>
#     <rdfs:label>fish</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Amphibian">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AnimalType"/>
#     <rdfs:label>amphibian</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Delaware">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>delaware</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Washington">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>washington</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Nebraska">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>nebraska</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Vermont">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>vermont</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Alabama">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>alabama</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Arizona">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>arizona</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Virginia">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>virginia</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Wyoming">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>wyoming</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="WestVirginia">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>west virginia</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Indiana">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>indiana</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Pennsylvania">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>pennsylvania</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="SouthCarolina">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>south carolina</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Colorado">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>colorado</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Alaska">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>alaska</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Mammal">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AnimalType"/>
#     <rdfs:label>mammal</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Bird">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AnimalType"/>
#     <rdfs:label>bird</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Fall">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Season"/>
#     <rdfs:label>fall</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="UsVirginIslands">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>u.s. virgin islands</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Michigan">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>michigan</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Mississippi">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>mississippi</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NewJersey">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>new jersey</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Iowa">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>iowa</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Utah">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>utah</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Summer">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Season"/>
#     <rdfs:label>summer</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Winter">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Season"/>
#     <rdfs:label>winter</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Ohio">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>ohio</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="SouthDakota">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>south dakota</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Moderate">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Difficulty"/>
#     <rdfs:label>moderate</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Reptile">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AnimalType"/>
#     <rdfs:label>reptile</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Minnesota">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>minnesota</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Connecticut">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>connecticut</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Hawaii">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>hawaii</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Florida">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>florida</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NorthDakota">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>north dakota</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Oklahoma">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>oklahoma</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Insect">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AnimalType"/>
#     <rdfs:label>insect</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Nevada">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>nevada</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Spring">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Season"/>
#     <rdfs:label>spring</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Illinois">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>illinois</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Oregon">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>oregon</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="California">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>california</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NorthCarolina">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>north carolina</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Idaho">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>idaho</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Arkansas">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>arkansas</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Georgia">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>georgia</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Maryland">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>maryland</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Montana">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>montana</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Tennessee">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>tennessee</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Texas">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>texas</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Maine">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>maine</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Easy">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Difficulty"/>
#     <rdfs:label>easy</rdfs:label>
#   </owl:NamedIndividual>
# </rdf:RDF>

# %%
'''
Webscraping Data for a Specific Link
'''
LINK = "https://www.cntraveler.com/gallery/the-best-hike-in-every-national-park"

response = requests.get(LINK)
soup = BeautifulSoup(response.text, 'html.parser')
figures = soup.find_all("figure", class_=re.compile(r"^GallerySlideFigure"))

parks = set()
national_parks  = [
    "Acadia National Park", "American Samoa National Park", "Arches National Park",
    "Badlands National Park", "Big Bend National Park", "Biscayne National Park",
    "Black Canyon of the Gunnison National Park", "Bryce Canyon National Park",
    "Canyonlands National Park", "Capitol Reef National Park", "Carlsbad Caverns National Park",
    "Channel Islands National Park", "Congaree National Park", "Crater Lake National Park",
    "Death Valley National Park", "Denali National Park", "Dry Tortugas National Park",
    "Everglades National Park", "Gates of the Arctic National Park", "Glacier Bay National Park",
    "Glacier National Park", "Grand Canyon National Park", "Grand Teton National Park",
    "Great Basin National Park", "Great Sand Dunes National Park", "Great Smoky Mountains National Park",
    "Haleakala National Park", "Hawaii Volcanoes National Park", "Hot Springs National Park",
    "Isle Royale National Park", "Joshua Tree National Park", "Katmai National Park",
    "Kenai Fjords National Park", "Kings Canyon National Park", "Kobuk Valley National Park",
    "Lake Clark National Park", "Lassen Volcanic National Park", "Mammoth Cave National Park",
    "Mesa Verde National Park", "Mount Rainier National Park", "North Cascades National Park",
    "Olympic National Park", "Petrified Forest National Park", "Pinnacles National Park",
    "Redwood National Park", "Rocky Mountain National Park", "Saguaro National Park",
    "Sequoia National Park", "Shenandoah National Park", "Theodore Roosevelt National Park",
    "Wind Cave National Park", "Wrangell St Elias National Park", "Yellowstone National Park",
    "Yosemite National Park", "Zion National Park", "Gateway Arch National Park",
    "Channel Islands National Park", "Black Canyon of the Gunnison National Park",
    "Cuyahoga Valley National Park", "Denali National Park", "Kings Canyon National Park",
    "Petrified Forest National Park", "US Virgin Islands National Park", "Voyageurs National Park",
    "White Sands National Park", "New River Gorge National Park", "Indiana Dunes National Park", "Guadalupe Mountains National Park"
]



for figure in figures:
    park = figure.find("h2").get_text(strip=True)
    park = park.replace(" and Preserve", "")  # Remove "and Preserve" from park names
    if park == ("National Park of American Samoa"):
      park = "American Samoa National Park"
    elif park == "Wrangell-St.Elias National Park":
      park = "Wrangell St Elias National Park"
    elif park == "Virgin Islands National Park":
      park = "US " + park
    elif park == "Haleakalā National Park":
      park = "Haleakala National Park"



    # if park in national_parks:
    #   print(park+" yes")
    # else:
    #   print(park+" no     "+park)



    paragraph = figure.find("figcaption").find("p")
    children = list(paragraph.children)

    name = children[1].strip()
    hike_len = children[3].split()[1].strip()
    hike_difficuty = children[5].split()[-1].strip()


    add_park_individual(graph, park)

    number_pattern = r"^\d+(\.\d+)?$"

    parks.add(park)

    if re.match(number_pattern, hike_len):
        add_hike_individual(graph, name, hike_difficuty, hike_len, park)

# tmp = 1
# for park in national_parks:
#   if park in parks:
#       print(park+" yes")
#       tmp+=1
#   else:
#     print(park+" no     "+park)
# print(tmp)
# print(len(national_parks))
# print(len(parks))
print_graph(graph)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <rdf:RDF
#   xmlns:oe-wtgw-ind="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/"
#  xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#  xml:base="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/"
#   xmlns:oe-wtgw="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/"
#   xmlns:dct="http://purl.org/dc/terms/"
#   xmlns:owl="http://www.w3.org/2002/07/owl#"
#   xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#   xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#   xmlns:cmns-av="https://www.omg.org/spec/Commons/AnnotationVocabulary/"
# >
#   <owl:NamedIndividual rdf:about="Kansas">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>kansas</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Wisconsin">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>wisconsin</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Kentucky">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>kentucky</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Massachusetts">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>massachusetts</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="RhodeIsland">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>rhode island</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Missouri">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>missouri</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Virginia">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>virginia</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="WestVirginia">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>west virginia</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Indiana">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>indiana</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Colorado">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>colorado</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Wyoming">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>wyoming</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Mississippi">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>mississippi</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Iowa">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>iowa</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Minnesota">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>minnesota</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Florida">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>florida</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="UsVirginIslands">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>u.s. virgin islands</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Nevada">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>nevada</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Illinois">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>illinois</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Summer">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Season"/>
#     <rdfs:label>summer</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:Ontology rdf:about="">
#     <dct:abstract>When to go where is a project that aims to promote outdoor exploration across the 63 National Parks in the United States. We would like to give people a tool that will allow them to find national parks that will fit any preferences that they may have. We want to give people as few excuses as possible for not pursing outdoor activities such as camping and hiking.
#
# To achieve this we are creating a semantically enabled application that will leverage an OWL ontology to answer user questions. Our interface will give users options to input preferences and using semantics we will identify the best parks that match a users particular criteria.</dct:abstract>
#     <dct:abstract>some description</dct:abstract>
#     <dct:creator>Annabelle Choi</dct:creator>
#     <dct:creator>Ben Rodgers</dct:creator>
#     <dct:creator>Samyuth Sagi</dct:creator>
#     <dct:creator>Tyler Layton</dct:creator>
#     <dct:license rdf:datatype="http://www.w3.org/2001/XMLSchema#anyURI">https://when-to-go-where--rpi-ontology-engineering.netlify.app/oe2024/when-to-go-where/license</dct:license>
#     <owl:imports rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/"/>
#     <dct:modified rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2024-11-30</dct:modified>
#     <dct:publisher>WhenToGoWhere</dct:publisher>
#     <owl:priorVersion rdf:resource="https://github.com/tetherless-world/ontology-engineering/blob/dac8dda75fb576d8551123076e10627d716549d9/oe2024/when-to-go-where/WhenToGoWhere-individuals.rdf"/>
#     <owl:priorVersion rdf:resource="https://github.com/tetherless-world/ontology-engineering/blob/114aa8ad617d0eeea3570d8d0f7a65eb21b862a9/oe2024/when-to-go-where/WhenToGoWhere-individuals.rdf"/>
#     <cmns-av:copyright>Copyright (c) 2024 Annabelle Choi, Ben Rodgers, Samyuth Sagi, Tyler Layton</cmns-av:copyright>
#     <owl:versionIRI rdf:resource="5.0"/>
#   </owl:Ontology>
#   <owl:NamedIndividual rdf:about="Fall">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Season"/>
#     <rdfs:label>fall</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="California">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>california</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Spring">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Season"/>
#     <rdfs:label>spring</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NorthDakota">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>north dakota</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="SouthDakota">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>south dakota</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Washington">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>washington</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="SouthCarolina">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>south carolina</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Utah">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>utah</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Montana">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>montana</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Maryland">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>maryland</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Pennsylvania">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>pennsylvania</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Louisiana">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>louisiana</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Maine">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>maine</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Bird">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AnimalType"/>
#     <rdfs:label>bird</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Delaware">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>delaware</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Oklahoma">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>oklahoma</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NewHampshire">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>new hampshire</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Arizona">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>arizona</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NewYork">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>new york</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Mammal">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AnimalType"/>
#     <rdfs:label>mammal</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Amphibian">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AnimalType"/>
#     <rdfs:label>amphibian</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Fish">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AnimalType"/>
#     <rdfs:label>fish</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Nebraska">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>nebraska</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Vermont">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>vermont</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Ohio">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>ohio</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Connecticut">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>connecticut</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Hawaii">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>hawaii</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Michigan">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>michigan</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Oregon">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>oregon</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="KobukValleyNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>kobuk valley national park</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NewMexico">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>new mexico</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NorthCarolina">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>north carolina</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Winter">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Season"/>
#     <rdfs:label>winter</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Arkansas">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>arkansas</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Tennessee">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>tennessee</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Georgia">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>georgia</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Idaho">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>idaho</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Texas">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>texas</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Reptile">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AnimalType"/>
#     <rdfs:label>reptile</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NewJersey">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>new jersey</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Insect">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AnimalType"/>
#     <rdfs:label>insect</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Alaska">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>alaska</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Alabama">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>alabama</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GreatSandDunesNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>great sand dunes national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="HighDune">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>high dune</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Challenging"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="GreatSandDunesNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BonanzaMineTrail">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>bonanza mine trail</rdfs:label>
#     <oe-wtgw:hasDifficulty>
#       <owl:NamedIndividual rdf:about="Challenging">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Difficulty"/>
#         <rdfs:label>challenging</rdfs:label>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasDifficulty>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="WrangellStEliasNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>wrangell-st. elias national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="BonanzaMineTrail"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BrandywineGorgeTrail">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>brandywine gorge trail</rdfs:label>
#     <oe-wtgw:hasDifficulty>
#       <owl:NamedIndividual rdf:about="Easy">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Difficulty"/>
#         <rdfs:label>easy</rdfs:label>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasDifficulty>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.5</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="CuyahogaValleyNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>cuyahoga valley national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="BrandywineGorgeTrail"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="FortJeffersonLoop">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>fort jefferson loop</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Easy"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.5</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="DryTortugasNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>dry tortugas national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="FortJeffersonLoop"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BigBendNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>big bend national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="WindowTrail">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>window trail</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.6</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="BigBendNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="MountRainierNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>mount rainier national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="SkylineTrailLoop">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>skyline trail loop</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Challenging"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.5</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="MountRainierNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="WindCaveNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>wind cave national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="LookoutPointAndCentennialTrailLoop">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>lookout point and centennial trail loop</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.2</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="WindCaveNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CastleTrailmedicineRootLoop">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>castle trail/medicine root loop</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Challenging"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">11</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="BadlandsNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>badlands national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="CastleTrailmedicineRootLoop"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GatewayArchTrail">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>gateway arch trail</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Easy"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.8</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="GatewayArchNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>gateway arch national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="GatewayArchTrail"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BartlettLakeTrail">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>bartlett lake trail</rdfs:label>
#     <oe-wtgw:hasDifficulty>
#       <owl:NamedIndividual rdf:about="Moderate">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Difficulty"/>
#         <rdfs:label>moderate</rdfs:label>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasDifficulty>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">10</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="GlacierBayNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>glacier bay national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="BartlettLakeTrail"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GrandCanyonNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>grand canyon national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="PlateauPointTrail">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>plateau point trail</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Challenging"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">12</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="GrandCanyonNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="AvalancheLake">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>avalanche lake</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.5</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="GlacierNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>glacier national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="AvalancheLake"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GlacierToHardingIcefield">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>glacier to harding icefield</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Challenging"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.2</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="KenaiFjordsNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>kenai fjords national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="GlacierToHardingIcefield"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="AmericanSamoaNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>american samoa national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="MountAlavaTrail">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>mount ‘alava trail</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Challenging"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.6</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="AmericanSamoaNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CowlesBogTrail">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>cowles bog trail</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.7</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="IndianaDunesNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>indiana dunes national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="CowlesBogTrail"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CondorGulchToHighPeaksLoop">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>condor gulch to high peaks loop</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Challenging"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.3</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="PinnaclesNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>pinnacles national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="CondorGulchToHighPeaksLoop"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="MesaVerdeNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>mesa verde national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="PetroglyphPointTrail">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>petroglyph point trail</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.4</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="MesaVerdeNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GrandWash">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>grand wash</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Easy"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="CapitolReefNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>capitol reef national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="GrandWash"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="SavageAlpineTrail">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>savage alpine trail</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Challenging"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="DenaliNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>denali national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="SavageAlpineTrail"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="SlidingSandsTrail">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>sliding sands trail</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Challenging"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">11</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="HaleakalaNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>haleakala national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="SlidingSandsTrail"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="LakeClarkNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>lake clark national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="KontrashibunaLake">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>kontrashibuna lake</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.5</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="LakeClarkNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="SequoiaNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>sequoia national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="LakesTrail">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>lakes trail</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Challenging"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">12.2</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="SequoiaNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="ChannelIslandsNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>channel islands national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="PelicanBayTrail">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>pelican bay trail</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="ChannelIslandsNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="WhiteSandsNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>white sands national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="DuneLifeNatureTrail">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>dune life nature trail</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Easy"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="WhiteSandsNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="TheWatchmanTrail">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>the watchman trail</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.3</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="ZionNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>zion national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="TheWatchmanTrail"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="HawksbillLoop">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>hawksbill loop</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.9</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="ShenandoahNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>shenandoah national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="HawksbillLoop"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="YosemiteNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>yosemite national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="PanoramaTrail">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>panorama trail</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Challenging"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">9</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="YosemiteNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="WillowHoleTrail">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>willow hole trail</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.2</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="JoshuaTreeNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>joshua tree national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="WillowHoleTrail"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="VoyageursNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>voyageurs national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="BlindAshBayTrail">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>blind ash bay trail</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Easy"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="VoyageursNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GuadalupePeakTrail">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>guadalupe peak trail</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Challenging"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8.4</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="GuadalupeMountainsNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>guadalupe mountains national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="GuadalupePeakTrail"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="LassenPeak">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>lassen peak</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Challenging"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.1</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="LassenVolcanicNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>lassen volcanic national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="LassenPeak"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GreatSmokyMountainsNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>great smoky mountains national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="AlumCaveTrail">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>alum cave trail</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="GreatSmokyMountainsNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="JordanPondToSouthBubbleSummit">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>jordan pond to south bubble summit</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="AcadiaNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>acadia national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="JordanPondToSouthBubbleSummit"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="ElliottKeyLoop">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>elliott key loop</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Easy"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.1</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="BiscayneNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>biscayne national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="ElliottKeyLoop"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CanyonlandsNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>canyonlands national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="GrandViewPoint">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>grand view point</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Easy"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.8</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="CanyonlandsNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="MistFalls">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>mist falls</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="KingsCanyonNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>kings canyon national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="MistFalls"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="WatchmanPeakTrail">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>watchman peak trail</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.7</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="CraterLakeNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>crater lake national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="WatchmanPeakTrail"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="RockyMountainNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>rocky mountain national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="MillsLake">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>mills lake</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.3</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="RockyMountainNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="IsleRoyaleNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>isle royale national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="ScovillePointTrail">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>scoville point trail</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Easy"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.2</oe-wtgw:hasDistance>
# ...
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="MammothCaveNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>mammoth cave national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="ExtendedHistoricTour">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>extended historic tour</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Easy"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="MammothCaveNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BrooksFallsAndRifflesPlatform">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>brooks falls and riffles platform</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Easy"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.1</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="KatmaiNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>katmai national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="BrooksFallsAndRifflesPlatform"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="KlaueaIkiTrail">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>kīlauea iki trail</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.3</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="HawaiiVolcanoesNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>hawaii volcanoes national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="KlaueaIkiTrail"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GrandTetonNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>grand teton national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="JennyLakeTrail">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>jenny lake trail</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.5</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="GrandTetonNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="RialtoBeachToHoleinthewall">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>rialto beach to hole-in-the-wall</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Easy"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="OlympicNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>olympic national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="RialtoBeachToHoleinthewall"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="RedwoodNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>redwood national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="TallTreesTrail">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>tall trees trail</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="RedwoodNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="JohnnyHornTrail">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>johnny horn trail</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="UsVirginIslandsNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>us virgin islands national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="JohnnyHornTrail"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="PeekabooLoopTrail">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>peekaboo loop trail</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Challenging"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.2</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="BryceCanyonNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>bryce canyon national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="PeekabooLoopTrail"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BoardwalkLoopTrail">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>boardwalk loop trail</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Easy"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.4</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="CongareeNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>congaree national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="BoardwalkLoopTrail"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BigRoomTrail">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>big room trail</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Easy"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.25</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="CarlsbadCavernsNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>carlsbad caverns national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="BigRoomTrail"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="AnhingaTrail">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>anhinga trail</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Easy"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0.8</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="EvergladesNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>everglades national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="AnhingaTrail"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BlackCanyonOfTheGunnisonNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>black canyon of the gunnison national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="ExclamationPoint">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>exclamation point</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Easy"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.9</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="BlackCanyonOfTheGunnisonNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="WassonPeakLoop">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>wasson peak loop</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Challenging"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">8</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="SaguaroNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>saguaro national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="WassonPeakLoop"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="ArrigetchPeaks">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>arrigetch peaks</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Challenging"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">32</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="GatesOfTheArcticNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>gates of the arctic national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="ArrigetchPeaks"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="HotSpringsMountainTrail">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>hot springs mountain trail</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Easy"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.3</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="HotSpringsNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>hot springs national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="HotSpringsMountainTrail"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GreatBasinNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>great basin national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="BristleconeAndGlacierTrail">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>bristlecone and glacier trail</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.8</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="GreatBasinNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="FairyFallsToImperialGeyser">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>fairy falls to imperial geyser</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">6.7</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="YellowstoneNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>yellowstone national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="FairyFallsToImperialGeyser"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CascadePassTrail">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>cascade pass trail</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.4</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="NorthCascadesNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>north cascades national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="CascadePassTrail"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="DeathValleyNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>death valley national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="GoldenCanyonAndGowerGulchFromZabriskiePoint">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>golden canyon and gower gulch from zabriskie point</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">7.8</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="DeathValleyNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CaprockCouleeLoop">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>caprock coulee loop</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.3</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="TheodoreRooseveltNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>theodore roosevelt national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="CaprockCouleeLoop"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
# </rdf:RDF>

# %%
'''
latitude and longitude
'''
# US National Parks with Exact Coordinates (Latitude, Longitude)
national_parks = [
    {"name": "Acadia", "state": "Maine", "latitude": 44.3386, "longitude": -68.2733},
    {"name": "American Samoa", "state": "American Samoa", "latitude": -14.2418, "longitude": -170.6819},
    {"name": "Arches", "state": "Utah", "latitude": 38.7331, "longitude": -109.5925},
    {"name": "Badlands", "state": "South Dakota", "latitude": 43.7554, "longitude": -102.4868},
    {"name": "Big Bend", "state": "Texas", "latitude": 29.2888, "longitude": -103.2634},
    {"name": "Biscayne", "state": "Florida", "latitude": 25.4652, "longitude": -80.2123},
    {"name": "Black Canyon of the Gunnison", "state": "Colorado", "latitude": 38.5704, "longitude": -107.7416},
    {"name": "Bryce Canyon", "state": "Utah", "latitude": 37.5930, "longitude": -112.1871},
    {"name": "Canyonlands", "state": "Utah", "latitude": 38.2186, "longitude": -109.9025},
    {"name": "Capitol Reef", "state": "Utah", "latitude": 38.3670, "longitude": -111.2615},
    {"name": "Carlsbad Caverns", "state": "New Mexico", "latitude": 32.1758, "longitude": -104.4468},
    {"name": "Channel Islands", "state": "California", "latitude": 34.0069, "longitude": -119.7030},
    {"name": "Congaree", "state": "South Carolina", "latitude": 33.8921, "longitude": -80.7747},
    {"name": "Crater Lake", "state": "Oregon", "latitude": 42.9405, "longitude": -122.1186},
    {"name": "Cuyahoga Valley", "state": "Ohio", "latitude": 41.2808, "longitude": -81.5578},
    {"name": "Death Valley", "state": "California/Nevada", "latitude": 36.4864, "longitude": -116.8361},
    {"name": "Denali", "state": "Alaska", "latitude": 63.1148, "longitude": -151.1926},
    {"name": "Dry Tortugas", "state": "Florida", "latitude": 24.6285, "longitude": -82.8732},
    {"name": "Everglades", "state": "Florida", "latitude": 25.3720, "longitude": -80.8995},
    {"name": "Gates of the Arctic", "state": "Alaska", "latitude": 67.4089, "longitude": -153.1423},
    {"name": "Gateway Arch", "state": "Missouri", "latitude": 38.6251, "longitude": -90.1868},
    {"name": "Glacier", "state": "Montana", "latitude": 48.7596, "longitude": -113.7870},
    {"name": "Glacier Bay", "state": "Alaska", "latitude": 58.6548, "longitude": -136.9075},
    {"name": "Grand Canyon", "state": "Arizona", "latitude": 36.0544, "longitude": -112.1401},
    {"name": "Grand Teton", "state": "Wyoming", "latitude": 43.7904, "longitude": -110.6818},
    {"name": "Great Basin", "state": "Nevada", "latitude": 38.7391, "longitude": -114.2384},
    {"name": "Great Sand Dunes", "state": "Colorado", "latitude": 37.7916, "longitude": -105.5943},
    {"name": "Great Smoky Mountains", "state": "Tennessee/North Carolina", "latitude": 35.6131, "longitude": -83.5532},
    {"name": "Guadalupe Mountains", "state": "Texas", "latitude": 31.9231, "longitude": -104.8619},
    {"name": "Haleakala", "state": "Hawaii", "latitude": 20.7204, "longitude": -156.1551},
    {"name": "Hawaii Volcanoes", "state": "Hawaii", "latitude": 19.4230, "longitude": -155.2866},
    {"name": "Hot Springs", "state": "Arkansas", "latitude": 34.5133, "longitude": -93.0631},
    {"name": "Indiana Dunes", "state": "Indiana", "latitude": 41.6533, "longitude": -87.0524},
    {"name": "Isle Royale", "state": "Michigan", "latitude": 48.0595, "longitude": -88.9093},
    {"name": "Joshua Tree", "state": "California", "latitude": 33.8734, "longitude": -115.9010},
    {"name": "Katmai", "state": "Alaska", "latitude": 58.5463, "longitude": -155.0626},
    {"name": "Kenai Fjords", "state": "Alaska", "latitude": 59.8521, "longitude": -149.6423},
    {"name": "Kings Canyon", "state": "California", "latitude": 36.8879, "longitude": -118.5551},
    {"name": "Kobuk Valley", "state": "Alaska", "latitude": 67.3351, "longitude": -159.1280},
    {"name": "Lake Clark", "state": "Alaska", "latitude": 60.4026, "longitude": -154.3230},
    {"name": "Lassen Volcanic", "state": "California", "latitude": 40.4978, "longitude": -121.4207},
    {"name": "Mammoth Cave", "state": "Kentucky", "latitude": 37.1866, "longitude": -86.1336},
    {"name": "Mesa Verde", "state": "Colorado", "latitude": 37.2309, "longitude": -108.4618},
    {"name": "Mount Rainier", "state": "Washington", "latitude": 46.8523, "longitude": -121.7603},
    {"name": "New River Gorge", "state": "West Virginia", "latitude": 38.0780, "longitude": -81.0817},
    {"name": "North Cascades", "state": "Washington", "latitude": 48.7718, "longitude": -121.2035},
    {"name": "Olympic", "state": "Washington", "latitude": 47.8021, "longitude": -123.6044},
    {"name": "Petrified Forest", "state": "Arizona", "latitude": 34.9097, "longitude": -109.8068},
    {"name": "Pinnacles", "state": "California", "latitude": 36.4908, "longitude": -121.1825},
    {"name": "Redwood", "state": "California", "latitude": 41.3134, "longitude": -124.0068},
    {"name": "Rocky Mountain", "state": "Colorado", "latitude": 40.3428, "longitude": -105.6836},
    {"name": "Saguaro", "state": "Arizona", "latitude": 32.2967, "longitude": -111.1665},
    {"name": "Sequoia", "state": "California", "latitude": 36.4863, "longitude": -118.5658},
    {"name": "Shenandoah", "state": "Virginia", "latitude": 38.5598, "longitude": -78.3732},
    {"name": "Theodore Roosevelt", "state": "North Dakota", "latitude": 46.9737, "longitude": -103.5387},
    {"name": "US Virgin Islands", "state": "U.S. Virgin Islands", "latitude": 18.3434, "longitude": -64.7081},
    {"name": "Voyageurs", "state": "Minnesota", "latitude": 48.4764, "longitude": -92.8261},
    {"name": "Wind Cave", "state": "South Dakota", "latitude": 43.6086, "longitude": -103.4850},
    {"name": "Wrangell St Elias", "state": "Alaska", "latitude": 61.7104, "longitude": -142.9865},
    {"name": "White Sands", "state": "New Mexico", "latitude": 32.7872, "longitude": -106.3257},
    {"name": "Yellowstone", "state": "Wyoming", "latitude": 44.4280, "longitude": -110.5885},
    {"name": "Yosemite", "state": "California", "latitude": 37.8651, "longitude": -119.5383},
    {"name": "Zion", "state": "Utah", "latitude": 37.2982, "longitude": -113.0263}
]


# List to store the parks with coordinates added
parks2 = []

for park in national_parks:
    matching_park_name = f"{park['name']} National Park"
    latitude = str(park['latitude'])
    longitude = str(park['longitude'])

    if matching_park_name not in parks2:
        parks2.append(matching_park_name)
        add_location_individual(graph, matching_park_name, latitude, longitude)

# %%
'''
Park codes for each of the national parks pulled from NPS Unit List
'''
park_codes = [
    {"name": "Acadia", "code": "ACAD"},
    {"name": "American Samoa", "code": "NPSA"},
    {"name": "Arches", "code": "ARCH"},
    {"name": "Badlands", "code": "BADL"},
    {"name": "Big Bend", "code": "BIBE"},
    {"name": "Biscayne", "code": "BISC"},
    {"name": "Black Canyon of the Gunnison", "code": "BLCA"},
    {"name": "Bryce Canyon", "code": "BRCA"},
    {"name": "Canyonlands", "code": "CANY"},
    {"name": "Capitol Reef", "code": "CARE"},
    {"name": "Carlsbad Caverns", "code": "CAVE"},
    {"name": "Channel Islands", "code": "CHIS"},
    {"name": "Congaree", "code": "CONG"},
    {"name": "Crater Lake", "code": "CRLA"},
    {"name": "Cuyahoga Valley", "code": "CUVA"},
    {"name": "Death Valley", "code": "DEVA"},
    {"name": "Denali", "code": "DEVA"},
    {"name": "Dry Tortugas", "code": "DRTO"},
    {"name": "Everglades", "code": "EVER"},
    {"name": "Gates of the Arctic", "code": "GAAR"},
    {"name": "Gateway Arch", "code": "JEFF"},
    {"name": "Glacier", "code": "GLAC"},
    {"name": "Glacier Bay", "code": "GLBA"},
    {"name": "Grand Canyon", "code": "GRCA"},
    {"name": "Grand Teton", "code": "GRTE"},
    {"name": "Great Basin", "code": "GRBA"},
    {"name": "Great Sand Dunes", "code": "GRSA"},
    {"name": "Great Smoky Mountains", "code": "GRSM"},
    {"name": "Guadalupe Mountains", "code": "GUMO"},
    {"name": "Haleakala", "code": "HALE"},
    {"name": "Hawaii Volcanoes", "code": "HAVO"},
    {"name": "Hot Springs", "code": "HOSP"},
    {"name": "Indiana Dunes", "code": "INDU"},
    {"name": "Isle Royale", "code": "ISRO"},
    {"name": "Joshua Tree", "code": "JOTR"},
    {"name": "Katmai", "code": "KATM"},
    {"name": "Kenai Fjords", "code": "KEFJ"},
    {"name": "Kings Canyon", "code": "KICA"},
    {"name": "Kobuk Valley", "code": "KOVA"},
    {"name": "Lake Clark", "code": "LACL"},
    {"name": "Lassen Volcanic", "code": "LAVO"},
    {"name": "Mammoth Cave", "code": "MACA"},
    {"name": "Mesa Verde", "code": "MEVE"},
    {"name": "Mount Rainier", "code": "MORA"},
    {"name": "New River Gorge", "code": "NERI"},
    {"name": "North Cascades", "code": "NOCA"},
    {"name": "Olympic", "code": "OLYM"},
    {"name": "Petrified Forest", "code": "PEFO"},
    {"name": "Pinnacles", "code": "PINN"},
    {"name": "Redwood", "code": "REDW"},
    {"name": "Rocky Mountain", "code": "ROMO"},
    {"name": "Saguaro", "code": "SAGU"},
    {"name": "Sequoia", "code": "SEQU"},
    {"name": "Shenandoah", "code": "SHEN"},
    {"name": "Theodore Roosevelt", "code": "THRO"},
    {"name": "US Virgin Islands", "code": "VIIS"},
    {"name": "Voyageurs", "code": "VOYA"},
    {"name": "Wind Cave", "code": "WICA"},
    {"name": "Wrangell St Elias", "code": "WRST"},
    {"name": "White Sands", "code": "WHSA"},
    {"name": "Yellowstone", "code": "YELL"},
    {"name": "Yosemite", "code": "YOSE"},
    {"name": "Zion", "code": "ZION"}
]

# make sure the names in codes match the names in national park
national_park_names = [park['name'] for park in national_parks]
park_code_names = [park['name'] for park in park_codes]
park_code_names == national_park_names
# Out:
# True

# %%
'''
Code block to get the seasonal stats for a specific park
'''
def get_seasonal_stats(code):
  # api and params
  url = "https://irmaservices.nps.gov/Stats/v1/visitation"
  params = {
      "unitCodes": code,
      "startMonth": 1,
      "startYear": 2023,
      "endMonth": 12,
      "endYear": 2023,
  }

  # send GET request
  try:
      # try to get a response
      response = requests.get(url, params=params)
      response.raise_for_status() # raise error for 4xx or 5xx

      # get the monthly visitor records
      soup = BeautifulSoup(response.content, "xml")
      records = soup.find_all("VisitationData")
      visitors = []
      for record in records:
          visitors.append(record.find("RecreationVisitors").text)

      # get seasons
      seasons = []
      for i in range(4):
        seasons.append(0)
        for j in range(3):
          seasons[-1] += int(visitors[i*3+j])
        seasons[-1] //= 3
      return seasons

  except requests.exceptions.RequestException as e:
      print(f"An error occurred: {e}")

for code in park_codes:
  # print(code['code'], code['name'] + " National Park")
  stats = get_seasonal_stats(code['code'])
  for vis, season in zip(stats, ["Winter", "Spring", "Summer", "Fall"]):
    add_visitors_individual(graph, code['name'] + " National Park", season, vis)
    # print("\t", vis, season)

# %%
print_graph(graph)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <rdf:RDF
#   xmlns:oe-wtgw-ind="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/"
#  xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#  xml:base="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/"
#   xmlns:oe-wtgw="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/"
#   xmlns:cmns-av="https://www.omg.org/spec/Commons/AnnotationVocabulary/"
#   xmlns:dct="http://purl.org/dc/terms/"
#   xmlns:Locations="https://www.omg.org/spec/Commons/Locations/"
#   xmlns:owl="http://www.w3.org/2002/07/owl#"
#   xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#   xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
# >
#   <owl:NamedIndividual rdf:about="Kansas">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>kansas</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CarlsbadCavernsNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>carlsbad caverns national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason>
#       <owl:NamedIndividual rdf:about="Spring">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Season"/>
#         <rdfs:label>spring</rdfs:label>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasSeason>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">38961</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="WindCaveNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>wind cave national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason>
#       <owl:NamedIndividual rdf:about="Winter">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Season"/>
#         <rdfs:label>winter</rdfs:label>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasSeason>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">12995</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="YellowstoneNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>yellowstone national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason>
#       <owl:NamedIndividual rdf:about="Summer">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Season"/>
#         <rdfs:label>summer</rdfs:label>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasSeason>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">884846</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="AmericanSamoaNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>american samoa national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">984</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="RhodeIsland">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>rhode island</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Virginia">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>virginia</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="YellowstoneNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>yellowstone national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">457124</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Indiana">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>indiana</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BryceCanyonNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>bryce canyon national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason>
#       <owl:NamedIndividual rdf:about="Fall">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Season"/>
#         <rdfs:label>fall</rdfs:label>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasSeason>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">139571</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="ShenandoahNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>shenandoah national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">41895</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BiscayneNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>biscayne national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">29790</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="DenaliNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>denali national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">55992</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Wyoming">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>wyoming</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NewRiverGorgeNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>new river gorge national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">237825</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BigBendNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>big bend national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">41553</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="LassenVolcanicNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>lassen volcanic national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">85635</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Iowa">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>iowa</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BlackCanyonOfTheGunnisonNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>black canyon of the gunnison national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10299</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BlackCanyonOfTheGunnisonNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>black canyon of the gunnison national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">31330</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="TheodoreRooseveltNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>theodore roosevelt national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">26045</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BryceCanyonNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>bryce canyon national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">340473</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CapitolReefNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>capitol reef national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">84478</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="UsVirginIslands">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>u.s. virgin islands</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Illinois">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>illinois</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="EvergladesNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>everglades national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">53317</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NewRiverGorgeNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>new river gorge national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">93532</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="EvergladesNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>everglades national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">59306</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="DeathValleyNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>death valley national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">114949</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="California">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>california</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="KingsCanyonNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>kings canyon national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">92783</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="AcadiaNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>acadia national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">728586</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="WindCaveNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>wind cave national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">68901</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="YellowstoneNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>yellowstone national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">118000</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GatesOfTheArcticNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>gates of the arctic national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">2674</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NorthDakota">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>north dakota</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GreatBasinNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>great basin national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">8108</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GlacierNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>glacier national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">642988</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CraterLakeNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>crater lake national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">33148</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="DryTortugasNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>dry tortugas national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">6948</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="DryTortugasNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>dry tortugas national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">5794</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="MesaVerdeNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>mesa verde national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">7322</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="SaguaroNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>saguaro national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">36943</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GlacierBayNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>glacier bay national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">135041</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CraterLakeNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>crater lake national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">24134</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GatesOfTheArcticNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>gates of the arctic national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">1007</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Maryland">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>maryland</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="KatmaiNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>katmai national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">20</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NewRiverGorgeNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>new river gorge national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">51746</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GatesOfTheArcticNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>gates of the arctic national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">0</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CongareeNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>congaree national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">19650</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="KingsCanyonNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>kings canyon national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10262</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Kentucky">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>kentucky</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GreatSmokyMountainsNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>great smoky mountains national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">615453</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="UsVirginIslandsNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>us virgin islands national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">20737</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="SaguaroNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>saguaro national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">83924</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="SaguaroNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>saguaro national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">129401</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="HotSpringsNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>hot springs national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">306385</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="ArchesNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>arches national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">161474</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="KobukValleyNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>kobuk valley national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">1263</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="PetrifiedForestNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>petrified forest national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">43539</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="UsVirginIslandsNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>us virgin islands national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">27806</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="SequoiaNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>sequoia national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">63278</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GrandTetonNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>grand teton national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">114734</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CraterLakeNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>crater lake national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">8863</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="KenaiFjordsNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>kenai fjords national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">37671</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="SaguaroNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>saguaro national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">86699</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CuyahogaValleyNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>cuyahoga valley national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">310761</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NewHampshire">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>new hampshire</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="PetrifiedForestNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>petrified forest national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">39115</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GlacierBayNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>glacier bay national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">14873</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="WindCaveNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>wind cave national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">18589</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="HaleakalaNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>haleakala national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">82573</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GreatSmokyMountainsNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>great smoky mountains national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">1147330</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="WindCaveNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>wind cave national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">97000</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:Ontology rdf:about="">
#     <dct:abstract>When to go where is a project that aims to promote outdoor exploration across the 63 National Parks in the United States. We would like to give people a tool that will allow them to find national parks that will fit any preferences that they may have. We want to give people as few excuses as possible for not pursing outdoor activities such as camping and hiking.
#
# To achieve this we are creating a semantically enabled application that will leverage an OWL ontology to answer user questions. Our interface will give users options to input preferences and using semantics we will identify the best parks that match a users particular criteria.</dct:abstract>
#     <dct:abstract>some description</dct:abstract>
#     <dct:creator>Annabelle Choi</dct:creator>
#     <dct:creator>Ben Rodgers</dct:creator>
#     <dct:creator>Samyuth Sagi</dct:creator>
#     <dct:creator>Tyler Layton</dct:creator>
#     <dct:license rdf:datatype="http://www.w3.org/2001/XMLSchema#anyURI">https://when-to-go-where--rpi-ontology-engineering.netlify.app/oe2024/when-to-go-where/license</dct:license>
#     <owl:imports rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/"/>
#     <dct:modified rdf:datatype="http://www.w3.org/2001/XMLSchema#date">2024-11-30</dct:modified>
#     <dct:publisher>WhenToGoWhere</dct:publisher>
#     <owl:priorVersion rdf:resource="https://github.com/tetherless-world/ontology-engineering/blob/dac8dda75fb576d8551123076e10627d716549d9/oe2024/when-to-go-where/WhenToGoWhere-individuals.rdf"/>
#     <owl:priorVersion rdf:resource="https://github.com/tetherless-world/ontology-engineering/blob/114aa8ad617d0eeea3570d8d0f7a65eb21b862a9/oe2024/when-to-go-where/WhenToGoWhere-individuals.rdf"/>
#     <cmns-av:copyright>Copyright (c) 2024 Annabelle Choi, Ben Rodgers, Samyuth Sagi, Tyler Layton</cmns-av:copyright>
#     <owl:versionIRI rdf:resource="5.0"/>
#   </owl:Ontology>
#   <owl:NamedIndividual rdf:about="HawaiiVolcanoesNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>hawaii volcanoes national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">139546</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="JoshuaTreeNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>joshua tree national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">341270</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="WhiteSandsNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>white sands national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">72068</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="PetrifiedForestNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>petrified forest national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">33430</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NorthCascadesNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>north cascades national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">970</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="WrangellStEliasNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>wrangell st elias national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">18518</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Nebraska">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>nebraska</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Utah">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>utah</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="VoyageursNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>voyageurs national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">5566</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CongareeNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>congaree national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">23677</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="DeathValleyNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>death valley national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">55992</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="MesaVerdeNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>mesa verde national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">58741</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GrandCanyonNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>grand canyon national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">486963</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GlacierBayNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>glacier bay national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">239</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Florida">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>florida</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="DeathValleyNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>death valley national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">82079</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CapitolReefNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>capitol reef national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">34527</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GuadalupeMountainsNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>guadalupe mountains national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">26534</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="LakeClarkNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>lake clark national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">0</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="WrangellStEliasNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>wrangell st elias national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">116</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="AmericanSamoaNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>american samoa national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">921</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="DenaliNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>denali national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">82079</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="ShenandoahNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>shenandoah national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">161965</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="IsleRoyaleNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>isle royale national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">7018</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="AcadiaNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>acadia national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">20440</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="KobukValleyNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>kobuk valley national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">1752</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="ChannelIslandsNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>channel islands national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">19246</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GrandCanyonNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>grand canyon national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">515758</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CapitolReefNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
# ...
#     <rdf:type rdf:resource="https://www.omg.org/spec/Commons/Locations/PhysicalLocation"/>
#     <rdfs:label>denali national park location</rdfs:label>
#     <Locations:hasLatitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">63.1148</Locations:hasLatitude>
#     <Locations:hasLongitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">-151.1926</Locations:hasLongitude>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BadlandsNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>badlands national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="CastleTrailmedicineRootLoop">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>castle trail/medicine root loop</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Challenging"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">11</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="BadlandsNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#     <Locations:hasLocation rdf:resource="BadlandsNationalParkLocation"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="HotSpringsNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>hot springs national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="HotSpringsMountainTrail">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>hot springs mountain trail</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Easy"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">3.3</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="HotSpringsNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#     <Locations:hasLocation rdf:resource="HotSpringsNationalParkLocation"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="ArrigetchPeaks">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>arrigetch peaks</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Challenging"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">32</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="GatesOfTheArcticNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>gates of the arctic national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="ArrigetchPeaks"/>
#         <Locations:hasLocation rdf:resource="GatesOfTheArcticNationalParkLocation"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GatesOfTheArcticNationalParkLocation">
#     <rdf:type rdf:resource="https://www.omg.org/spec/Commons/Locations/PhysicalLocation"/>
#     <rdfs:label>gates of the arctic national park location</rdfs:label>
#     <Locations:hasLatitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">67.4089</Locations:hasLatitude>
#     <Locations:hasLongitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">-153.1423</Locations:hasLongitude>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BartlettLakeTrail">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>bartlett lake trail</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">10</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="GlacierBayNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>glacier bay national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="BartlettLakeTrail"/>
#         <Locations:hasLocation rdf:resource="GlacierBayNationalParkLocation"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="DenaliNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>denali national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="SavageAlpineTrail">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>savage alpine trail</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Challenging"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="DenaliNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#     <Locations:hasLocation rdf:resource="DenaliNationalParkLocation"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CapitolReefNationalParkLocation">
#     <rdf:type rdf:resource="https://www.omg.org/spec/Commons/Locations/PhysicalLocation"/>
#     <rdfs:label>capitol reef national park location</rdfs:label>
#     <Locations:hasLatitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">38.367</Locations:hasLatitude>
#     <Locations:hasLongitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">-111.2615</Locations:hasLongitude>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="IndianaDunesNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>indiana dunes national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="CowlesBogTrail">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>cowles bog trail</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Moderate"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4.7</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="IndianaDunesNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#     <Locations:hasLocation rdf:resource="IndianaDunesNationalParkLocation"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GatewayArchNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>gateway arch national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="GatewayArchTrail">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>gateway arch trail</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Easy"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">1.8</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="GatewayArchNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#     <Locations:hasLocation>
#       <owl:NamedIndividual rdf:about="GatewayArchNationalParkLocation">
#         <rdf:type rdf:resource="https://www.omg.org/spec/Commons/Locations/PhysicalLocation"/>
#         <rdfs:label>gateway arch national park location</rdfs:label>
#         <Locations:hasLatitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">38.6251</Locations:hasLatitude>
#         <Locations:hasLongitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">-90.1868</Locations:hasLongitude>
#       </owl:NamedIndividual>
#     </Locations:hasLocation>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="AmericanSamoaNationalParkLocation">
#     <rdf:type rdf:resource="https://www.omg.org/spec/Commons/Locations/PhysicalLocation"/>
#     <rdfs:label>american samoa national park location</rdfs:label>
#     <Locations:hasLatitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">-14.2418</Locations:hasLatitude>
#     <Locations:hasLongitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">-170.6819</Locations:hasLongitude>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="MammothCaveNationalParkLocation">
#     <rdf:type rdf:resource="https://www.omg.org/spec/Commons/Locations/PhysicalLocation"/>
#     <rdfs:label>mammoth cave national park location</rdfs:label>
#     <Locations:hasLatitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">37.1866</Locations:hasLatitude>
#     <Locations:hasLongitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">-86.1336</Locations:hasLongitude>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="SequoiaNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>sequoia national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="LakesTrail">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>lakes trail</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Challenging"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">12.2</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="SequoiaNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#     <Locations:hasLocation rdf:resource="SequoiaNationalParkLocation"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BlackCanyonOfTheGunnisonNationalPark">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#     <rdfs:label>black canyon of the gunnison national park</rdfs:label>
#     <oe-wtgw:hasHike>
#       <owl:NamedIndividual rdf:about="ExclamationPoint">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#         <rdfs:label>exclamation point</rdfs:label>
#         <oe-wtgw:hasDifficulty rdf:resource="Easy"/>
#         <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2.9</oe-wtgw:hasDistance>
#         <oe-wtgw:isHikeOf rdf:resource="BlackCanyonOfTheGunnisonNationalPark"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasHike>
#     <Locations:hasLocation>
#       <owl:NamedIndividual rdf:about="BlackCanyonOfTheGunnisonNationalParkLocation">
#         <rdf:type rdf:resource="https://www.omg.org/spec/Commons/Locations/PhysicalLocation"/>
#         <rdfs:label>black canyon of the gunnison national park location</rdfs:label>
#         <Locations:hasLatitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">38.5704</Locations:hasLatitude>
#         <Locations:hasLongitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">-107.7416</Locations:hasLongitude>
#       </owl:NamedIndividual>
#     </Locations:hasLocation>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="KenaiFjordsNationalParkLocation">
#     <rdf:type rdf:resource="https://www.omg.org/spec/Commons/Locations/PhysicalLocation"/>
#     <rdfs:label>kenai fjords national park location</rdfs:label>
#     <Locations:hasLatitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">59.8521</Locations:hasLatitude>
#     <Locations:hasLongitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">-149.6423</Locations:hasLongitude>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="IsleRoyaleNationalParkLocation">
#     <rdf:type rdf:resource="https://www.omg.org/spec/Commons/Locations/PhysicalLocation"/>
#     <rdfs:label>isle royale national park location</rdfs:label>
#     <Locations:hasLatitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">48.0595</Locations:hasLatitude>
#     <Locations:hasLongitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">-88.9093</Locations:hasLongitude>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="YosemiteNationalParkLocation">
#     <rdf:type rdf:resource="https://www.omg.org/spec/Commons/Locations/PhysicalLocation"/>
#     <rdfs:label>yosemite national park location</rdfs:label>
#     <Locations:hasLatitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">37.8651</Locations:hasLatitude>
#     <Locations:hasLongitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">-119.5383</Locations:hasLongitude>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="KingsCanyonNationalParkLocation">
#     <rdf:type rdf:resource="https://www.omg.org/spec/Commons/Locations/PhysicalLocation"/>
#     <rdfs:label>kings canyon national park location</rdfs:label>
#     <Locations:hasLatitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">36.8879</Locations:hasLatitude>
#     <Locations:hasLongitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">-118.5551</Locations:hasLongitude>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="AcadiaNationalParkLocation">
#     <rdf:type rdf:resource="https://www.omg.org/spec/Commons/Locations/PhysicalLocation"/>
#     <rdfs:label>acadia national park location</rdfs:label>
#     <Locations:hasLatitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">44.3386</Locations:hasLatitude>
#     <Locations:hasLongitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">-68.2733</Locations:hasLongitude>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="ExtendedHistoricTour">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>extended historic tour</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Easy"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf>
#       <owl:NamedIndividual rdf:about="MammothCaveNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>mammoth cave national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="ExtendedHistoricTour"/>
#         <Locations:hasLocation rdf:resource="MammothCaveNationalParkLocation"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isHikeOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GlacierBayNationalParkLocation">
#     <rdf:type rdf:resource="https://www.omg.org/spec/Commons/Locations/PhysicalLocation"/>
#     <rdfs:label>glacier bay national park location</rdfs:label>
#     <Locations:hasLatitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">58.6548</Locations:hasLatitude>
#     <Locations:hasLongitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">-136.9075</Locations:hasLongitude>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CongareeNationalParkLocation">
#     <rdf:type rdf:resource="https://www.omg.org/spec/Commons/Locations/PhysicalLocation"/>
#     <rdfs:label>congaree national park location</rdfs:label>
#     <Locations:hasLatitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">33.8921</Locations:hasLatitude>
#     <Locations:hasLongitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">-80.7747</Locations:hasLongitude>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="LakeClarkNationalParkLocation">
#     <rdf:type rdf:resource="https://www.omg.org/spec/Commons/Locations/PhysicalLocation"/>
#     <rdfs:label>lake clark national park location</rdfs:label>
#     <Locations:hasLatitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">60.4026</Locations:hasLatitude>
#     <Locations:hasLongitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">-154.323</Locations:hasLongitude>
#   </owl:NamedIndividual>
# </rdf:RDF>

# %%
'''
Authentication logic sourced from chatgpt
'''
# Authenticate the user
auth.authenticate_user()

# Authenticate with gspread using Google Drive credentials
from google.auth import default
creds, _ = default()
gc = gspread.authorize(creds)

# Open the spreadsheet by its URL
spreadsheet_url = "https://docs.google.com/spreadsheets/d/1pMLCErMIz6XHOSjQQ5GmqtnM3jViEiDlIjKGQZIhmF0/edit?gid=0"
spreadsheet = gc.open_by_url(spreadsheet_url)

# Access the first sheet (or specify a sheet by name)
worksheet = spreadsheet.get_worksheet(0)


# Convert the worksheet data to a Pandas DataFrame
import pandas as pd
data = get_as_dataframe(worksheet)
data = data.iloc[:63, :6]

park_data = data.iloc[1:, 0]

for index, row in data.iterrows():
  park = row[0]
  state = row[1]

  for temp, season in zip(row[2:], ["Winter", "Spring", "Summer", "Fall"]):
    match = re.search(r"(-?\d+\.?\d*)", temp)

    if match:
      add_temperature_individual(graph, park, season, match.group(0))

  if park in parks:
    for state in state.split('/'):
      add_park_individual(graph, park, state=state)

# count
# print(data)
# Out:
# <ipython-input-326-81eeddcb4a75>:28: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   park = row[0]
# <ipython-input-326-81eeddcb4a75>:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   state = row[1]

# %%
# graph = create_graph()
'''
Authentication logic sourced from chatgpt
'''
# Authenticate the user
auth.authenticate_user()

# Authenticate with gspread using Google Drive credentials
from google.auth import default
creds, _ = default()
gc = gspread.authorize(creds)


# animal url
animal_url = "https://docs.google.com/spreadsheets/d/1IH1ug7IjVp5TTmG1XsqL2j9rmOilxGJ0aMvdKxDbeeI/edit?gid=1560123062#gid=1560123062"
animal_sheet = gc.open_by_url(animal_url)

# Access the first sheet (or specify a sheet by name)
an_sheet = animal_sheet.get_worksheet(0)

# Convert the worksheet data to a Pandas DataFrame
import pandas as pd
data = get_as_dataframe(an_sheet)
data = data.iloc[:414, :3]


for index, row in data.iterrows():
  name = row[1]
  type = row[2]
  park = row[0]
  new_park = park.replace(" ", "")
  add_animal_individual(graph, name, type, new_park)
  # print(name +" "+type)

print_graph(graph)
# count
# print(data)
# Out:
# <ipython-input-327-ded579b29566>:28: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   name = row[1]
# <ipython-input-327-ded579b29566>:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   type = row[2]
# <ipython-input-327-ded579b29566>:30: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   park = row[0]
# <?xml version="1.0" encoding="utf-8"?>
# <rdf:RDF
#   xmlns:oe-wtgw-ind="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/"
#  xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#  xml:base="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/"
#   xmlns:oe-wtgw="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/"
#   xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#   xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#   xmlns:owl="http://www.w3.org/2002/07/owl#"
#   xmlns:cmns-av="https://www.omg.org/spec/Commons/AnnotationVocabulary/"
#   xmlns:dct="http://purl.org/dc/terms/"
#   xmlns:Locations="https://www.omg.org/spec/Commons/Locations/"
# >
#   <owl:NamedIndividual rdf:about="CarlsbadCavernsNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>carlsbad caverns national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason>
#       <owl:NamedIndividual rdf:about="Spring">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Season"/>
#         <rdfs:label>spring</rdfs:label>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasSeason>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">38961</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CommonSharptailedSnake">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>common sharp-tailed snake</rdfs:label>
#     <oe-wtgw:isAnimalType>
#       <owl:NamedIndividual rdf:about="Reptile">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AnimalType"/>
#         <rdfs:label>reptile</rdfs:label>
#       </owl:NamedIndividual>
#     </oe-wtgw:isAnimalType>
#     <oe-wtgw:isAnimalOf>
#       <owl:NamedIndividual rdf:about="YosemiteNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>yosemite national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="PanoramaTrail"/>
#         <Locations:hasLocation rdf:resource="YosemiteNationalParkLocation"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="YosemiteNationalParkWinterAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="YosemiteNationalParkSpringAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="YosemiteNationalParkSummerAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="YosemiteNationalParkFallAvgTemperature"/>
#         <oe-wtgw:hasState rdf:resource="California"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isAnimalOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="KarnerBlueButterfly">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>karner blue butterfly</rdfs:label>
#     <oe-wtgw:isAnimalType>
#       <owl:NamedIndividual rdf:about="Insect">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AnimalType"/>
#         <rdfs:label>insect</rdfs:label>
#       </owl:NamedIndividual>
#     </oe-wtgw:isAnimalType>
#     <oe-wtgw:isAnimalOf>
#       <owl:NamedIndividual rdf:about="IndianaDunesNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>indiana dunes national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="CowlesBogTrail"/>
#         <Locations:hasLocation rdf:resource="IndianaDunesNationalParkLocation"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="IndianaDunesNationalParkWinterAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="IndianaDunesNationalParkSpringAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="IndianaDunesNationalParkSummerAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="IndianaDunesNationalParkFallAvgTemperature"/>
#         <oe-wtgw:hasState rdf:resource="Indiana"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isAnimalOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="WindCaveNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>wind cave national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason>
#       <owl:NamedIndividual rdf:about="Winter">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Season"/>
#         <rdfs:label>winter</rdfs:label>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasSeason>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">12995</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GreatPlainsToad">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>great plains toad</rdfs:label>
#     <oe-wtgw:isAnimalType>
#       <owl:NamedIndividual rdf:about="Amphibian">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AnimalType"/>
#         <rdfs:label>amphibian</rdfs:label>
#       </owl:NamedIndividual>
#     </oe-wtgw:isAnimalType>
#     <oe-wtgw:isAnimalOf>
#       <owl:NamedIndividual rdf:about="GrandCanyonNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>grand canyon national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="PlateauPointTrail"/>
#         <Locations:hasLocation rdf:resource="GrandCanyonNationalParkLocation"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="GrandCanyonNationalParkWinterAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="GrandCanyonNationalParkSpringAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="GrandCanyonNationalParkSummerAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="GrandCanyonNationalParkFallAvgTemperature"/>
#         <oe-wtgw:hasState rdf:resource="Arizona"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isAnimalOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="YellowstoneNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>yellowstone national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason>
#       <owl:NamedIndividual rdf:about="Summer">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Season"/>
#         <rdfs:label>summer</rdfs:label>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasSeason>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">884846</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="SmallmouthBass">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>smallmouth bass</rdfs:label>
#     <oe-wtgw:isAnimalType>
#       <owl:NamedIndividual rdf:about="Fish">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AnimalType"/>
#         <rdfs:label>fish</rdfs:label>
#       </owl:NamedIndividual>
#     </oe-wtgw:isAnimalType>
#     <oe-wtgw:isAnimalOf rdf:resource="YosemiteNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="FernaldCuckooBumbleBee">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>fernald cuckoo bumble bee</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Insect"/>
#     <oe-wtgw:isAnimalOf>
#       <owl:NamedIndividual rdf:about="GlacierNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>glacier national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="AvalancheLake"/>
#         <Locations:hasLocation rdf:resource="GlacierNationalParkLocation"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="GlacierNationalParkWinterAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="GlacierNationalParkSpringAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="GlacierNationalParkSummerAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="GlacierNationalParkFallAvgTemperature"/>
#         <oe-wtgw:hasState rdf:resource="Montana"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isAnimalOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="LakeSturgeon">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>lake sturgeon</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Fish"/>
#     <oe-wtgw:isAnimalOf>
#       <owl:NamedIndividual rdf:about="CuyahogaValleyNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>cuyahoga valley national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="BrandywineGorgeTrail"/>
#         <Locations:hasLocation rdf:resource="CuyahogaValleyNationalParkLocation"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="CuyahogaValleyNationalParkWinterAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="CuyahogaValleyNationalParkSpringAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="CuyahogaValleyNationalParkSummerAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="CuyahogaValleyNationalParkFallAvgTemperature"/>
#         <oe-wtgw:hasState rdf:resource="Ohio"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isAnimalOf>
#     <oe-wtgw:isAnimalOf rdf:resource="IndianaDunesNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BiscayneNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>biscayne national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason>
#       <owl:NamedIndividual rdf:about="Fall">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Season"/>
#         <rdfs:label>fall</rdfs:label>
#       </owl:NamedIndividual>
#     </oe-wtgw:hasSeason>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">29790</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NorthernRubberBoa">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>northern rubber boa</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Reptile"/>
#     <oe-wtgw:isAnimalOf rdf:resource="GlacierNationalPark"/>
#     <oe-wtgw:isAnimalOf>
#       <owl:NamedIndividual rdf:about="GrandTetonNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>grand teton national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="JennyLakeTrail"/>
#         <Locations:hasLocation rdf:resource="GrandTetonNationalParkLocation"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="GrandTetonNationalParkWinterAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="GrandTetonNationalParkSpringAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="GrandTetonNationalParkSummerAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="GrandTetonNationalParkFallAvgTemperature"/>
#         <oe-wtgw:hasState rdf:resource="Wyoming"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isAnimalOf>
#     <oe-wtgw:isAnimalOf>
#       <owl:NamedIndividual rdf:about="OlympicNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>olympic national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="RialtoBeachToHoleinthewall"/>
#         <Locations:hasLocation rdf:resource="OlympicNationalParkLocation"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="OlympicNationalParkWinterAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="OlympicNationalParkSpringAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="OlympicNationalParkSummerAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="OlympicNationalParkFallAvgTemperature"/>
#         <oe-wtgw:hasState rdf:resource="Washington"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isAnimalOf>
#     <oe-wtgw:isAnimalOf>
#       <owl:NamedIndividual rdf:about="YellowstoneNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>yellowstone national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="FairyFallsToImperialGeyser"/>
#         <Locations:hasLocation rdf:resource="YellowstoneNationalParkLocation"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="YellowstoneNationalParkWinterAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="YellowstoneNationalParkSpringAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="YellowstoneNationalParkSummerAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="YellowstoneNationalParkFallAvgTemperature"/>
#         <oe-wtgw:hasState rdf:resource="Wyoming"/>
#         <oe-wtgw:hasState rdf:resource="Montana"/>
#         <oe-wtgw:hasState rdf:resource="Idaho"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isAnimalOf>
#     <oe-wtgw:isAnimalOf rdf:resource="YosemiteNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="ColoradoRiverToad">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>colorado river toad</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Amphibian"/>
#     <oe-wtgw:isAnimalOf rdf:resource="GrandCanyonNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="ZonetailedHawk">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>zone-tailed hawk</rdfs:label>
#     <oe-wtgw:isAnimalType>
#       <owl:NamedIndividual rdf:about="Bird">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AnimalType"/>
#         <rdfs:label>bird</rdfs:label>
#       </owl:NamedIndividual>
#     </oe-wtgw:isAnimalType>
#     <oe-wtgw:isAnimalOf rdf:resource="GrandCanyonNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="RedWolf">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>red wolf</rdfs:label>
#     <oe-wtgw:isAnimalType>
#       <owl:NamedIndividual rdf:about="Mammal">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AnimalType"/>
#         <rdfs:label>mammal</rdfs:label>
#       </owl:NamedIndividual>
#     </oe-wtgw:isAnimalType>
#     <oe-wtgw:isAnimalOf>
#       <owl:NamedIndividual rdf:about="HotSpringsNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>hot springs national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="HotSpringsMountainTrail"/>
#         <Locations:hasLocation rdf:resource="HotSpringsNationalParkLocation"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="HotSpringsNationalParkWinterAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="HotSpringsNationalParkSpringAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="HotSpringsNationalParkSummerAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="HotSpringsNationalParkFallAvgTemperature"/>
#         <oe-wtgw:hasState rdf:resource="Arkansas"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isAnimalOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="RedleggedHamBeetle">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>redlegged ham beetle</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Insect"/>
#     <oe-wtgw:isAnimalOf rdf:resource="YellowstoneNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="DenaliNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>denali national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">55992</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NewRiverGorgeNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>new river gorge national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">237825</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="PrairieRingneckSnake">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>prairie ringneck snake</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Reptile"/>
#     <oe-wtgw:isAnimalOf rdf:resource="HotSpringsNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="PacificTreeFrog">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>pacific tree frog</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Amphibian"/>
#     <oe-wtgw:isAnimalOf rdf:resource="OlympicNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="LassenVolcanicNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>lassen volcanic national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">85635</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Iowa">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>iowa</rdfs:label>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BlackRacer">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>black racer</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Reptile"/>
#     <oe-wtgw:isAnimalOf rdf:resource="CuyahogaValleyNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BlackCanyonOfTheGunnisonNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>black canyon of the gunnison national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">10299</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="EasternWormsnake">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>eastern wormsnake</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Reptile"/>
#     <oe-wtgw:isAnimalOf>
#       <owl:NamedIndividual rdf:about="GreatSmokyMountainsNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>great smoky mountains national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="AlumCaveTrail"/>
#         <Locations:hasLocation rdf:resource="GreatSmokyMountainsNationalParkLocation"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="GreatSmokyMountainsNationalParkWinterAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="GreatSmokyMountainsNationalParkSpringAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="GreatSmokyMountainsNationalParkSummerAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="GreatSmokyMountainsNationalParkFallAvgTemperature"/>
#         <oe-wtgw:hasState rdf:resource="Tennessee"/>
#         <oe-wtgw:hasState rdf:resource="NorthCarolina"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isAnimalOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BlackCanyonOfTheGunnisonNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>black canyon of the gunnison national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">31330</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CanyonTreefrog">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>canyon treefrog</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Amphibian"/>
#     <oe-wtgw:isAnimalOf rdf:resource="GrandCanyonNationalPark"/>
#     <oe-wtgw:isAnimalOf>
#       <owl:NamedIndividual rdf:about="JoshuaTreeNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>joshua tree national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="WillowHoleTrail"/>
#         <Locations:hasLocation rdf:resource="JoshuaTreeNationalParkLocation"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="JoshuaTreeNationalParkWinterAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="JoshuaTreeNationalParkSpringAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="JoshuaTreeNationalParkSummerAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="JoshuaTreeNationalParkFallAvgTemperature"/>
#         <oe-wtgw:hasState rdf:resource="California"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isAnimalOf>
#     <oe-wtgw:isAnimalOf>
#       <owl:NamedIndividual rdf:about="ZionNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>zion national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="TheWatchmanTrail"/>
#         <Locations:hasLocation rdf:resource="ZionNationalParkLocation"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="ZionNationalParkWinterAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="ZionNationalParkSpringAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="ZionNationalParkSummerAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="ZionNationalParkFallAvgTemperature"/>
#         <oe-wtgw:hasState rdf:resource="Utah"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isAnimalOf>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NetwingedMidges">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>net-winged midges</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Insect"/>
#     <oe-wtgw:isAnimalOf rdf:resource="GrandTetonNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="SanDiegoSouthernAlligatorLizard">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>san diego (southern) alligator lizard</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Reptile"/>
#     <oe-wtgw:isAnimalOf rdf:resource="YosemiteNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="JuneSucker">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>june sucker</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Fish"/>
#     <oe-wtgw:isAnimalOf rdf:resource="YellowstoneNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="TheodoreRooseveltNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>theodore roosevelt national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">26045</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CapitolReefNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>capitol reef national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">84478</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="MountainSucker">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>mountain sucker</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Fish"/>
#     <oe-wtgw:isAnimalOf rdf:resource="GrandTetonNationalPark"/>
#     <oe-wtgw:isAnimalOf>
#       <owl:NamedIndividual rdf:about="RockyMountainNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>rocky mountain national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="MillsLake"/>
#         <Locations:hasLocation rdf:resource="RockyMountainNationalParkLocation"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="RockyMountainNationalParkWinterAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="RockyMountainNationalParkSpringAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="RockyMountainNationalParkSummerAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="RockyMountainNationalParkFallAvgTemperature"/>
#         <oe-wtgw:hasState rdf:resource="Colorado"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isAnimalOf>
#     <oe-wtgw:isAnimalOf rdf:resource="YellowstoneNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="ZionNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="HolarcticTreefrogs">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>holarctic treefrogs</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Amphibian"/>
#     <oe-wtgw:isAnimalOf rdf:resource="GreatSmokyMountainsNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="EvergladesNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>everglades national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">53317</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NewRiverGorgeNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>new river gorge national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">93532</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="AppalachianBrown">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>appalachian brown</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Insect"/>
#     <oe-wtgw:isAnimalOf rdf:resource="IndianaDunesNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="EvergladesNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>everglades national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">59306</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="DeathValleyNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>death valley national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">114949</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="DeceptiveBomolocha">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>deceptive bomolocha</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Insect"/>
#     <oe-wtgw:isAnimalOf rdf:resource="GreatSmokyMountainsNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="WindCaveNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>wind cave national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">68901</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GoldenEagle">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>golden eagle</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Bird"/>
#     <oe-wtgw:isAnimalOf>
#       <owl:NamedIndividual rdf:about="BryceCanyonNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>bryce canyon national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="PeekabooLoopTrail"/>
#         <Locations:hasLocation rdf:resource="BryceCanyonNationalParkLocation"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="BryceCanyonNationalParkWinterAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="BryceCanyonNationalParkSpringAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="BryceCanyonNationalParkSummerAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="BryceCanyonNationalParkFallAvgTemperature"/>
#         <oe-wtgw:hasState rdf:resource="Utah"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isAnimalOf>
#     <oe-wtgw:isAnimalOf rdf:resource="GlacierNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="GrandCanyonNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="GrandTetonNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="GreatSmokyMountainsNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="HotSpringsNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="IndianaDunesNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="OlympicNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="RockyMountainNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="YellowstoneNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="YosemiteNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="ZionNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="AmericanBison">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>american bison</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Mammal"/>
#     <oe-wtgw:isAnimalOf rdf:resource="GrandCanyonNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="GrandTetonNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="GreatSmokyMountainsNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="IndianaDunesNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="RockyMountainNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GatesOfTheArcticNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>gates of the arctic national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">2674</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GreatBasinNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>great basin national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">8108</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="WesternFoxsnake">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>western foxsnake</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Reptile"/>
#     <oe-wtgw:isAnimalOf rdf:resource="IndianaDunesNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="WesternLongnoseSucker">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>western longnose sucker</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Fish"/>
#     <oe-wtgw:isAnimalOf rdf:resource="RockyMountainNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="ArgentineAnt">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>argentine ant</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Insect"/>
#     <oe-wtgw:isAnimalOf rdf:resource="JoshuaTreeNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="DryTortugasNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>dry tortugas national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">5794</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BigheadedFly">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>big-headed fly</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Insect"/>
#     <oe-wtgw:isAnimalOf rdf:resource="GreatSmokyMountainsNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="SaguaroNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>saguaro national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">36943</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Skipjack">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>skipjack</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Fish"/>
#     <oe-wtgw:isAnimalOf rdf:resource="IndianaDunesNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GatesOfTheArcticNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>gates of the arctic national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">1007</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BajaCaliforniaTreefrog">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>baja california treefrog</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Amphibian"/>
#     <oe-wtgw:isAnimalOf rdf:resource="JoshuaTreeNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NelsonsBighornSheep">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>nelson's bighorn sheep</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Mammal"/>
#     <oe-wtgw:isAnimalOf rdf:resource="JoshuaTreeNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="SacramentoPikeminnow">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>sacramento pikeminnow</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Fish"/>
#     <oe-wtgw:isAnimalOf rdf:resource="YosemiteNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="KatmaiNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>katmai national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">20</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NewRiverGorgeNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>new river gorge national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">51746</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CoopersHawk">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>cooper's hawk</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Bird"/>
#     <oe-wtgw:isAnimalOf>
#       <owl:NamedIndividual rdf:about="AcadiaNationalPark">
#         <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/NationalPark"/>
#         <rdfs:label>acadia national park</rdfs:label>
#         <oe-wtgw:hasHike rdf:resource="JordanPondToSouthBubbleSummit"/>
#         <Locations:hasLocation rdf:resource="AcadiaNationalParkLocation"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="AcadiaNationalParkWinterAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="AcadiaNationalParkSpringAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="AcadiaNationalParkSummerAvgTemperature"/>
#         <oe-wtgw:hasAvgSeasonalTemperature rdf:resource="AcadiaNationalParkFallAvgTemperature"/>
#         <oe-wtgw:hasState rdf:resource="Maine"/>
#       </owl:NamedIndividual>
#     </oe-wtgw:isAnimalOf>
#     <oe-wtgw:isAnimalOf rdf:resource="BryceCanyonNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="CuyahogaValleyNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="GlacierNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="GrandCanyonNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="GrandTetonNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="GreatSmokyMountainsNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="HotSpringsNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="IndianaDunesNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="JoshuaTreeNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="OlympicNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="RockyMountainNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="YellowstoneNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="YosemiteNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="ZionNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CordilleranMeadowFly">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>cordilleran meadow fly</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Insect"/>
#     <oe-wtgw:isAnimalOf rdf:resource="OlympicNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="FowlersToad">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>fowler's toad</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Amphibian"/>
#     <oe-wtgw:isAnimalOf rdf:resource="GreatSmokyMountainsNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="HotSpringsNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="IndianaDunesNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GreatSmokyMountainsNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>great smoky mountains national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">615453</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="EasternAmericanToad">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>eastern american toad</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Amphibian"/>
#     <oe-wtgw:isAnimalOf rdf:resource="GreatSmokyMountainsNationalPark"/>
#     <oe-wtgw:isAnimalOf rdf:resource="IndianaDunesNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="SaguaroNationalParkWinterAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>saguaro national park winter average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">129401</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="HotSpringsNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>hot springs national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">306385</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="YellowstoneNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>yellowstone national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">457124</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="ArchesNationalParkSummerAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>arches national park summer average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">161474</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="SoldierFlies">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Animal"/>
#     <rdfs:label>soldier flies</rdfs:label>
#     <oe-wtgw:isAnimalType rdf:resource="Insect"/>
#     <oe-wtgw:isAnimalOf rdf:resource="GrandTetonNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="UsVirginIslandsNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>us virgin islands national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">27806</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="SequoiaNationalParkSpringAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>sequoia national park spring average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasVisitors rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">63278</oe-wtgw:hasVisitors>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GrandTetonNationalParkFallAvgVisitors">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalVisitors"/>
#     <rdfs:label>grand teton national park fall average visitors</rdfs:label>
#     <oe-wtgw:hasSeason rdf:resource="Fall"/>
# ...
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="NewRiverGorgeNationalParkSummerAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>new river gorge national park summer average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">75</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="AcadiaNationalParkFallAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>acadia national park fall average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">55</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GreatSmokyMountainsNationalParkSpringAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>great smoky mountains national park spring average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">60</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="YosemiteNationalParkFallAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>yosemite national park fall average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">50</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="ZionNationalParkWinterAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>zion national park winter average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">40</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CuyahogaValleyNationalParkFallAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>cuyahoga valley national park fall average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">50</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BiscayneNationalParkSummerAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>biscayne national park summer average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">90</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="PeekabooLoopTrail">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>peekaboo loop trail</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Challenging"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">5.2</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf rdf:resource="BryceCanyonNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="HotSpringsNationalParkFallAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>hot springs national park fall average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">60</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BiscayneNationalParkLocation">
#     <rdf:type rdf:resource="https://www.omg.org/spec/Commons/Locations/PhysicalLocation"/>
#     <rdfs:label>biscayne national park location</rdfs:label>
#     <Locations:hasLatitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">25.4652</Locations:hasLatitude>
#     <Locations:hasLongitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">-80.2123</Locations:hasLongitude>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="AcadiaNationalParkSummerAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>acadia national park summer average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">70</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="AcadiaNationalParkLocation">
#     <rdf:type rdf:resource="https://www.omg.org/spec/Commons/Locations/PhysicalLocation"/>
#     <rdfs:label>acadia national park location</rdfs:label>
#     <Locations:hasLatitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">44.3386</Locations:hasLatitude>
#     <Locations:hasLongitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">-68.2733</Locations:hasLongitude>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="RialtoBeachToHoleinthewall">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/Hike"/>
#     <rdfs:label>rialto beach to hole-in-the-wall</rdfs:label>
#     <oe-wtgw:hasDifficulty rdf:resource="Easy"/>
#     <oe-wtgw:hasDistance rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">4</oe-wtgw:hasDistance>
#     <oe-wtgw:isHikeOf rdf:resource="OlympicNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="YellowstoneNationalParkWinterAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>yellowstone national park winter average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">15</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="RockyMountainNationalParkFallAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>rocky mountain national park fall average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">45</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="HotSpringsNationalParkWinterAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>hot springs national park winter average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">40</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BiscayneNationalParkSpringAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>biscayne national park spring average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">77</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CuyahogaValleyNationalParkSpringAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>cuyahoga valley national park spring average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">50</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="WrangellStEliasNationalParkLocation">
#     <rdf:type rdf:resource="https://www.omg.org/spec/Commons/Locations/PhysicalLocation"/>
#     <rdfs:label>wrangell st elias national park location</rdfs:label>
#     <Locations:hasLatitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">61.7104</Locations:hasLatitude>
#     <Locations:hasLongitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">-142.9865</Locations:hasLongitude>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GrandTetonNationalParkFallAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>grand teton national park fall average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">40</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GreatSandDunesNationalParkWinterAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>great sand dunes national park winter average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">25</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Idaho">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>idaho</rdfs:label>
#     <oe-wtgw:hasPark rdf:resource="YellowstoneNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="GreatBasinNationalParkSummerAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>great basin national park summer average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">75</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Ohio">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>ohio</rdfs:label>
#     <oe-wtgw:hasPark rdf:resource="CuyahogaValleyNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BryceCanyonNationalParkLocation">
#     <rdf:type rdf:resource="https://www.omg.org/spec/Commons/Locations/PhysicalLocation"/>
#     <rdfs:label>bryce canyon national park location</rdfs:label>
#     <Locations:hasLatitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">37.593</Locations:hasLatitude>
#     <Locations:hasLongitude rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">-112.1871</Locations:hasLongitude>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="JoshuaTreeNationalParkFallAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>joshua tree national park fall average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">70</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="Virginia">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/State"/>
#     <rdfs:label>virginia</rdfs:label>
#     <oe-wtgw:hasPark rdf:resource="ShenandoahNationalPark"/>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="PetrifiedForestNationalParkWinterAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>petrified forest national park winter average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">40</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="HawaiiVolcanoesNationalParkFallAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>hawaii volcanoes national park fall average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">70</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="BadlandsNationalParkSpringAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>badlands national park spring average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">45</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="OlympicNationalParkWinterAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>olympic national park winter average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Winter"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">35</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="AcadiaNationalParkSpringAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>acadia national park spring average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Spring"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">50</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="MountRainierNationalParkFallAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>mount rainier national park fall average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Fall"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">40</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
#   <owl:NamedIndividual rdf:about="CuyahogaValleyNationalParkSummerAvgTemperature">
#     <rdf:type rdf:resource="https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/AvgSeasonalTemperature"/>
#     <rdfs:label>cuyahoga valley national park summer average temperature</rdfs:label>
#     <oe-wtgw:temperatureHasSeason rdf:resource="Summer"/>
#     <oe-wtgw:hasTemperature rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">75</oe-wtgw:hasTemperature>
#   </owl:NamedIndividual>
# </rdf:RDF>

# %%
# Query 1
query="""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX oe-wtgw: <https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/>
PREFIX oe-wtgw-ind: <https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/>
SELECT ?hike
WHERE {
    # ?hike oe-wtgw:isHikeOf oe-wtgw-ind:ArchesNationalPark
}
"""

for row in graph.query(query):
  print(row)
# Out:
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/DoubleOArch'),)

# %%
# Query 2
query="""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX oe-wtgw: <https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/>
PREFIX oe-wtgw-ind: <https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/>
PREFIX Locations: <https://www.omg.org/spec/Commons/Locations/>
SELECT ?park ?latitude
WHERE  {
    # ?park Locations:hasLocation ?location .
    # ?location Locations:hasLatitude ?latitude .
    FILTER(datatype(?latitude) = xsd:decimal)
}
ORDER BY DESC(?latitude)
"""

for row in graph.query(query):
  print(row)
# Out:
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/GatesOfTheArcticNationalPark'), rdflib.term.Literal('67.4089', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/KobukValleyNationalPark'), rdflib.term.Literal('67.3351', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/DenaliNationalPark'), rdflib.term.Literal('63.1148', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/WrangellStEliasNationalPark'), rdflib.term.Literal('61.7104', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/LakeClarkNationalPark'), rdflib.term.Literal('60.4026', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/KenaiFjordsNationalPark'), rdflib.term.Literal('59.8521', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/GlacierBayNationalPark'), rdflib.term.Literal('58.6548', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/KatmaiNationalPark'), rdflib.term.Literal('58.5463', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/NorthCascadesNationalPark'), rdflib.term.Literal('48.7718', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/GlacierNationalPark'), rdflib.term.Literal('48.7596', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/VoyageursNationalPark'), rdflib.term.Literal('48.4764', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/IsleRoyaleNationalPark'), rdflib.term.Literal('48.0595', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/OlympicNationalPark'), rdflib.term.Literal('47.8021', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/TheodoreRooseveltNationalPark'), rdflib.term.Literal('46.9737', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/MountRainierNationalPark'), rdflib.term.Literal('46.8523', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/YellowstoneNationalPark'), rdflib.term.Literal('44.428', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/AcadiaNationalPark'), rdflib.term.Literal('44.3386', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/GrandTetonNationalPark'), rdflib.term.Literal('43.7904', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/BadlandsNationalPark'), rdflib.term.Literal('43.7554', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/WindCaveNationalPark'), rdflib.term.Literal('43.6086', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/CraterLakeNationalPark'), rdflib.term.Literal('42.9405', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/IndianaDunesNationalPark'), rdflib.term.Literal('41.6533', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/RedwoodNationalPark'), rdflib.term.Literal('41.3134', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/CuyahogaValleyNationalPark'), rdflib.term.Literal('41.2808', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/LassenVolcanicNationalPark'), rdflib.term.Literal('40.4978', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/RockyMountainNationalPark'), rdflib.term.Literal('40.3428', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/GreatBasinNationalPark'), rdflib.term.Literal('38.7391', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/ArchesNationalPark'), rdflib.term.Literal('38.7331', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/GatewayArchNationalPark'), rdflib.term.Literal('38.6251', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/BlackCanyonOfTheGunnisonNationalPark'), rdflib.term.Literal('38.5704', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/ShenandoahNationalPark'), rdflib.term.Literal('38.5598', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/CapitolReefNationalPark'), rdflib.term.Literal('38.367', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/CanyonlandsNationalPark'), rdflib.term.Literal('38.2186', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/NewRiverGorgeNationalPark'), rdflib.term.Literal('38.078', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/YosemiteNationalPark'), rdflib.term.Literal('37.8651', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/GreatSandDunesNationalPark'), rdflib.term.Literal('37.7916', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/BryceCanyonNationalPark'), rdflib.term.Literal('37.593', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/ZionNationalPark'), rdflib.term.Literal('37.2982', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/MesaVerdeNationalPark'), rdflib.term.Literal('37.2309', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/MammothCaveNationalPark'), rdflib.term.Literal('37.1866', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/KingsCanyonNationalPark'), rdflib.term.Literal('36.8879', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/PinnaclesNationalPark'), rdflib.term.Literal('36.4908', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/DeathValleyNationalPark'), rdflib.term.Literal('36.4864', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/SequoiaNationalPark'), rdflib.term.Literal('36.4863', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/GrandCanyonNationalPark'), rdflib.term.Literal('36.0544', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/GreatSmokyMountainsNationalPark'), rdflib.term.Literal('35.6131', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/PetrifiedForestNationalPark'), rdflib.term.Literal('34.9097', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/HotSpringsNationalPark'), rdflib.term.Literal('34.5133', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/ChannelIslandsNationalPark'), rdflib.term.Literal('34.0069', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/CongareeNationalPark'), rdflib.term.Literal('33.8921', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/JoshuaTreeNationalPark'), rdflib.term.Literal('33.8734', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/WhiteSandsNationalPark'), rdflib.term.Literal('32.7872', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/SaguaroNationalPark'), rdflib.term.Literal('32.2967', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/CarlsbadCavernsNationalPark'), rdflib.term.Literal('32.1758', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/GuadalupeMountainsNationalPark'), rdflib.term.Literal('31.9231', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/BigBendNationalPark'), rdflib.term.Literal('29.2888', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/BiscayneNationalPark'), rdflib.term.Literal('25.4652', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/EvergladesNationalPark'), rdflib.term.Literal('25.372', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/DryTortugasNationalPark'), rdflib.term.Literal('24.6285', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/HaleakalaNationalPark'), rdflib.term.Literal('20.7204', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/HawaiiVolcanoesNationalPark'), rdflib.term.Literal('19.423', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/UsVirginIslandsNationalPark'), rdflib.term.Literal('18.3434', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/AmericanSamoaNationalPark'), rdflib.term.Literal('-14.2418', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))

# %%
# Query 3
query="""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX oe-wtgw-ind: <https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/>
PREFIX oe-wtgw: <https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/>
SELECT ?park
WHERE {
    # ?park rdf:type oe-wtgw:NationalPark .
    # ?park oe-wtgw:hasState oe-wtgw-ind:Maine .
}
"""

for row in graph.query(query):
  print(row)
# Out:
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/AcadiaNationalPark'),)

# %%
# Query 4
query="""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX oe-wtgw: <https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/>
PREFIX oe-wtgw-ind: <https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/>
PREFIX Locations: <https://www.omg.org/spec/Commons/Locations/>
SELECT ?park ?longitude ?summerTemp
WHERE {
    # ?park rdf:type oe-wtgw:NationalPark .
    # ?park Locations:hasLocation ?location .
    # ?location Locations:hasLongitude ?longitude .
    # ?park oe-wtgw:hasAvgSeasonalTemperature ?tempInd .
    # ?tempInd rdf:type oe-wtgw:AvgSeasonalTemperature .
    # ?tempInd oe-wtgw:temperatureHasSeason oe-wtgw-ind:Summer .
    # ?tempInd oe-wtgw:hasTemperature ?summerTemp .
    FILTER(?longitude >= -110 && ?longitude <= -82)
}
ORDER BY ASC(?summerTemp)
"""

for row in graph.query(query):
  print(row)
# Out:
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/IsleRoyaleNationalPark'), rdflib.term.Literal('-88.9093', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.Literal('65', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/BlackCanyonOfTheGunnisonNationalPark'), rdflib.term.Literal('-107.7416', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.Literal('70', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/RockyMountainNationalPark'), rdflib.term.Literal('-105.6836', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.Literal('70', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/VoyageursNationalPark'), rdflib.term.Literal('-92.8261', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.Literal('70', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/IndianaDunesNationalPark'), rdflib.term.Literal('-87.0524', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.Literal('75', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/TheodoreRooseveltNationalPark'), rdflib.term.Literal('-103.5387', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.Literal('75', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/WindCaveNationalPark'), rdflib.term.Literal('-103.485', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.Literal('75', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/BadlandsNationalPark'), rdflib.term.Literal('-102.4868', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.Literal('80', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/GatewayArchNationalPark'), rdflib.term.Literal('-90.1868', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.Literal('80', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/GreatSandDunesNationalPark'), rdflib.term.Literal('-105.5943', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.Literal('80', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/GreatSmokyMountainsNationalPark'), rdflib.term.Literal('-83.5532', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.Literal('80', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/HotSpringsNationalPark'), rdflib.term.Literal('-93.0631', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.Literal('80', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/MammothCaveNationalPark'), rdflib.term.Literal('-86.1336', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.Literal('80', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/MesaVerdeNationalPark'), rdflib.term.Literal('-108.4618', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.Literal('80', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/CarlsbadCavernsNationalPark'), rdflib.term.Literal('-104.4468', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.Literal('85', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/DryTortugasNationalPark'), rdflib.term.Literal('-82.8732', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.Literal('85', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/PetrifiedForestNationalPark'), rdflib.term.Literal('-109.8068', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.Literal('90', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/ArchesNationalPark'), rdflib.term.Literal('-109.5925', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.Literal('95', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/BigBendNationalPark'), rdflib.term.Literal('-103.2634', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.Literal('95', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/CanyonlandsNationalPark'), rdflib.term.Literal('-109.9025', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.Literal('95', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/GuadalupeMountainsNationalPark'), rdflib.term.Literal('-104.8619', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.Literal('95', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/WhiteSandsNationalPark'), rdflib.term.Literal('-106.3257', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.Literal('95', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))

# %%
# Query 5
query="""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX oe-wtgw: <https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/>
PREFIX oe-wtgw-ind: <https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/>
SELECT ?park ?summerTemp ?hike ?distance
WHERE {
    # ?park rdf:type oe-wtgw:NationalPark .
    # ?park oe-wtgw:hasAvgSeasonalTemperature ?tempInd .
    # ?tempInd rdf:type oe-wtgw:AvgSeasonalTemperature .
    # ?tempInd oe-wtgw:temperatureHasSeason oe-wtgw-ind:Summer .
    # ?tempInd oe-wtgw:hasTemperature ?summerTemp .
    # ?park oe-wtgw:hasHike ?hike .
    # ?hike oe-wtgw:hasDistance ?distance .
    FILTER(?distance <= 2)
}
ORDER BY ASC(?summerTemp)
"""

for row in graph.query(query):
  print(row)
# Out:
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/CraterLakeNationalPark'), rdflib.term.Literal('65', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/WatchmanPeakTrail'), rdflib.term.Literal('1.7', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/CuyahogaValleyNationalPark'), rdflib.term.Literal('75', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/BrandywineGorgeTrail'), rdflib.term.Literal('1.5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/GatewayArchNationalPark'), rdflib.term.Literal('80', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/GatewayArchTrail'), rdflib.term.Literal('1.8', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/MammothCaveNationalPark'), rdflib.term.Literal('80', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/ExtendedHistoricTour'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/CarlsbadCavernsNationalPark'), rdflib.term.Literal('85', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/BigRoomTrail'), rdflib.term.Literal('1.25', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/DryTortugasNationalPark'), rdflib.term.Literal('85', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/FortJeffersonLoop'), rdflib.term.Literal('0.5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/BiscayneNationalPark'), rdflib.term.Literal('90', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/ElliottKeyLoop'), rdflib.term.Literal('1.1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/EvergladesNationalPark'), rdflib.term.Literal('90', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/AnhingaTrail'), rdflib.term.Literal('0.8', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/PetrifiedForestNationalPark'), rdflib.term.Literal('90', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/BlueMesaTrail'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/CanyonlandsNationalPark'), rdflib.term.Literal('95', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/GrandViewPoint'), rdflib.term.Literal('1.8', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/WhiteSandsNationalPark'), rdflib.term.Literal('95', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')), rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/DuneLifeNatureTrail'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))

# %%
# Query 6
query="""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX oe-wtgw: <https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere/>
PREFIX oe-wtgw-ind: <https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/>
SELECT ?park ?hike ?distance
WHERE {
    # ?park rdf:type oe-wtgw:NationalPark .
    # ?park oe-wtgw:hasState oe-wtgw-ind:California .
    # ?park oe-wtgw:hasHike ?hike .
    # ?hike oe-wtgw:hasDistance ?distance .
    FILTER(datatype(?distance) = xsd:decimal)
}
ORDER BY DESC(?distance)
"""

for row in graph.query(query):
  print(row)
# Out:
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/SequoiaNationalPark'), rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/LakesTrail'), rdflib.term.Literal('12.2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/YosemiteNationalPark'), rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/PanoramaTrail'), rdflib.term.Literal('9', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/KingsCanyonNationalPark'), rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/MistFalls'), rdflib.term.Literal('8', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/DeathValleyNationalPark'), rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/GoldenCanyonAndGowerGulchFromZabriskiePoint'), rdflib.term.Literal('7.8', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/JoshuaTreeNationalPark'), rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/WillowHoleTrail'), rdflib.term.Literal('7.2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/PinnaclesNationalPark'), rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/CondorGulchToHighPeaksLoop'), rdflib.term.Literal('5.3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/LassenVolcanicNationalPark'), rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/LassenPeak'), rdflib.term.Literal('5.1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/ChannelIslandsNationalPark'), rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/PelicanBayTrail'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/RedwoodNationalPark'), rdflib.term.URIRef('https://tw.rpi.edu/ontology-engineering/oe2024/when-to-go-where/WhenToGoWhere-individuals/TallTreesTrail'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))

# %%
# !pip install fuzzywuzzy
# Out:
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.10/dist-packages (0.18.0)

# %%
from fuzzywuzzy import process

list1 = ['Acadia National Park', 'Arches National Park', 'Badlands National Park', 'Big Bend National Park',
         'Biscayne National Park', 'Black Canyon of the Gunnison National Park', 'Bryce Canyon National Park',
         'Canyonlands National Park', 'Capitol Reef National Park', 'Carlsbad Caverns National Park',
         'Channel Islands National Park', 'Congaree National Park', 'Crater Lake National Park',
         'Cuyahoga Valley National Park', 'Death Valley National Park', 'Denali National Park and Preserve',
         'Dry Tortugas National Park', 'Everglades National Park', 'Gates of the Arctic National Park',
         'Gateway Arch National Park', 'Glacier National Park', 'Glacier Bay National Park',
         'Grand Canyon National Park', 'Grand Teton National Park', 'Great Basin National Park',
         'Great Sand Dunes National Park', 'Great Smoky Mountains National Park', 'Guadalupe Mountains National Park',
         'Haleakalā National Park', 'Hawaii Volcanoes National Park', 'Hot Springs National Park',
         'Indiana Dunes National Park', 'Isle Royale National Park', 'Joshua Tree National Park',
         'Katmai National Park and Preserve', 'Kenai Fjords National Park', 'Kings Canyon National Park',
         'Kobuk Valley National Park', 'Lake Clark National Park', 'Lassen Volcanic National Park',
         'Mammoth Cave National Park', 'Mesa Verde National Park', 'Mount Rainier National Park',
         'National Park of American Samoa', 'New River Gorge National Park', 'North Cascades National Park',
         'Olympic National Park', 'Petrified Forest National Park', 'Pinnacles National Park',
         'Redwood National Park', 'Rocky Mountain National Park', 'Saguaro National Park',
         'Sequoia National Park', 'Shenandoah National Park', 'Theodore Roosevelt National Park',
         'Virgin Islands National Park', 'Voyageurs National Park', 'White Sands National Park',
         'Wind Cave National Park', 'Wrangell-St.Elias National Park and Preserve',
         'Yellowstone National Park', 'Yosemite National Park', 'Zion National Park']

list2 = ['American Samoa National Park', 'Arches National Park', 'Badlands National Park', 'Big Bend National Park',
         'Biscayne National Park', 'Black Canyon of the Gunnison National Park', 'Bryce Canyon National Park',
         'Canyonlands National Park', 'Capitol Reef National Park', 'Carlsbad Caverns National Park',
         'Channel Islands National Park', 'Congaree National Park', 'Crater Lake National Park',
         'Death Valley National Park', 'Denali National Park', 'Dry Tortugas National Park',
         'Everglades National Park', 'Gates of the Arctic National Park', 'Glacier Bay National Park',
         'Glacier National Park', 'Grand Canyon National Park', 'Grand Teton National Park',
         'Great Basin National Park', 'Great Sand Dunes National Park', 'Great Smoky Mountains National Park',
         'Haleakalā National Park', 'Hawaii Volcanoes National Park', 'Hot Springs National Park',
         'Isle Royale National Park', 'Joshua Tree National Park', 'Katmai National Park',
         'Kenai Fjords National Park', 'Kings Canyon National Park', 'Kobuk Valley National Park',
         'Lake Clark National Park', 'Lassen Volcanic National Park', 'Mammoth Cave National Park',
         'Mesa Verde National Park', 'Mount Rainier National Park', 'North Cascades National Park',
         'Olympic National Park', 'Petrified Forest National Park', 'Pinnacles National Park',
         'Redwood National and State Parks', 'Rocky Mountain National Park', 'Saguaro National Park',
         'Sequoia National Park', 'Shenandoah National Park', 'Theodore Roosevelt National Park',
         'Virgin Islands National Park', 'Wind Cave National Park', 'Wrangell-St. Elias National Park',
         'Yellowstone National Park', 'Yosemite National Park', 'Zion National Park',
         'The Gateway Arch National Park', 'Channel Islands National Park',
         'Black Canyon of the Gunnison National Park', 'Cuyahoga Valley National Park',
         'Denali National Park', 'Kings Canyon National Park', 'Petrified Forest National Park']

# Match list1 names to list2
matches = {}
for park in list1:
    best_match, score = process.extractOne(park, list2)
    if score > 89:  # Adjust threshold as needed
        matches[park] = best_match

# Display results
for park, match in matches.items():
    print(f"{park} -> {match}")

print(len(list(matches.items())))
# Out:
# Arches National Park -> Arches National Park
# Badlands National Park -> Badlands National Park
# Big Bend National Park -> Big Bend National Park
# Biscayne National Park -> Biscayne National Park
# Black Canyon of the Gunnison National Park -> Black Canyon of the Gunnison National Park
# Bryce Canyon National Park -> Bryce Canyon National Park
# Canyonlands National Park -> Canyonlands National Park
# Capitol Reef National Park -> Capitol Reef National Park
# Carlsbad Caverns National Park -> Carlsbad Caverns National Park
# Channel Islands National Park -> Channel Islands National Park
# Congaree National Park -> Congaree National Park
# Crater Lake National Park -> Crater Lake National Park
# Cuyahoga Valley National Park -> Cuyahoga Valley National Park
# Death Valley National Park -> Death Valley National Park
# Denali National Park and Preserve -> Denali National Park
# Dry Tortugas National Park -> Dry Tortugas National Park
# Everglades National Park -> Everglades National Park
# Gates of the Arctic National Park -> Gates of the Arctic National Park
# Gateway Arch National Park -> The Gateway Arch National Park
# Glacier National Park -> Glacier National Park
# Glacier Bay National Park -> Glacier Bay National Park
# Grand Canyon National Park -> Grand Canyon National Park
# Grand Teton National Park -> Grand Teton National Park
# Great Basin National Park -> Great Basin National Park
# Great Sand Dunes National Park -> Great Sand Dunes National Park
# Great Smoky Mountains National Park -> Great Smoky Mountains National Park
# Haleakalā National Park -> Haleakalā National Park
# Hawaii Volcanoes National Park -> Hawaii Volcanoes National Park
# Hot Springs National Park -> Hot Springs National Park
# Isle Royale National Park -> Isle Royale National Park
# Joshua Tree National Park -> Joshua Tree National Park
# Katmai National Park and Preserve -> Katmai National Park
# Kenai Fjords National Park -> Kenai Fjords National Park
# Kings Canyon National Park -> Kings Canyon National Park
# Kobuk Valley National Park -> Kobuk Valley National Park
# Lake Clark National Park -> Lake Clark National Park
# Lassen Volcanic National Park -> Lassen Volcanic National Park
# Mammoth Cave National Park -> Mammoth Cave National Park
# Mesa Verde National Park -> Mesa Verde National Park
# Mount Rainier National Park -> Mount Rainier National Park
# National Park of American Samoa -> American Samoa National Park
# North Cascades National Park -> North Cascades National Park
# Olympic National Park -> Olympic National Park
# Petrified Forest National Park -> Petrified Forest National Park
# Pinnacles National Park -> Pinnacles National Park
# Rocky Mountain National Park -> Rocky Mountain National Park
# Saguaro National Park -> Saguaro National Park
# Sequoia National Park -> Sequoia National Park
# Shenandoah National Park -> Shenandoah National Park
# Theodore Roosevelt National Park -> Theodore Roosevelt National Park
# Virgin Islands National Park -> Virgin Islands National Park
# Wind Cave National Park -> Wind Cave National Park
# Wrangell-St.Elias National Park and Preserve -> Wrangell-St. Elias National Park
# Yellowstone National Park -> Yellowstone National Park
# Yosemite National Park -> Yosemite National Park
# Zion National Park -> Zion National Park
# 56
